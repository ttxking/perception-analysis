# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy.stats import  kruskal, mannwhitneyu, wilcoxon, skew, rankdata
from mapper import continent_mapper, politicians_db
import warnings
warnings.filterwarnings('ignore')

# Set style for plots
plt.style.use('default')
sns.set_palette("husl")

# %%
key_traits = ["competence", "likable", "trustworthy", "approachable", "charismatic", 
                "aggressive", "friendly", "professional", "visually_appealing", "professionally_designed",
                "aggressive_poster", "inspirational", "manipulative", "boring", "misleading",
                "match_pol_comm", "credible_typo_color", "background", "typo_attention", "support", "interested_in"]

skew_traits = ['misleading', 'aggressive_poster', 'aggressive', 'manipulative', 'inspirational', 'professional']

# %%
def epsilon_interpretation(epsilon_sq):
    """
    Interpret the epsilon square value.
    """
    if epsilon_sq < 0.01:
        print("Negligible effect size (very small practical impact).")
    elif epsilon_sq < 0.06:
        print("Small effect size (small practical impact).")
    elif epsilon_sq < 0.14:
        print("Medium effect size (moderate practical impact).")
    else:
        print("Large effect size (substantial practical impact).")
        
def rank_biserial_matched_pairs(before, after):
    """
    Calculate matched-pairs rank-biserial correlation (Wilcoxon signed-rank test effect size)

    Parameters:
    before, after: array-like, paired observations

    Returns:
    r_rb: matched-pairs rank-biserial correlation (-1 to 1)
    """

    before = np.array(before)
    after = np.array(after)

    # Remove pairs where either value is NaN
    valid_pairs = ~(np.isnan(before) | np.isnan(after))
    before = before[valid_pairs]
    after = after[valid_pairs]

    # Calculate differences
    differences = after - before

    # Remove zero differences
    non_zero_diff = differences[differences != 0]
    if len(non_zero_diff) == 0:
        return 0

    # Get ranks of absolute differences
    ranks = rankdata(np.abs(non_zero_diff))
    # Positive and negative differences
    W_pos = np.sum(ranks[non_zero_diff > 0])
    W_neg = np.sum(ranks[non_zero_diff < 0])

    # Rank-biserial correlation
    r_rb = (W_pos - W_neg) / (W_pos + W_neg)
    return r_rb

# %%
class Phase1Analyser:
    def __init__(self, phase1_files):
        """
        Initialize the analyzer with both phase datasets
        """
        self.continent_mapping = continent_mapper
        self.politician_info = politicians_db
        self.phase1_df = self.load_and_clean_data(phase1_files)
    
    
    def load_and_clean_data(self, filepath):
        """
        Load and clean the data, with politician identification
        """
        dfs = []  # list to collect all DataFrames

        for path in filepath:
            df = pd.read_csv(path)

            # Extract politician short name from file path, e.g., "phase1_data/albanese_phase1_data.csv"
            politician_name = path.split("/")[1].split('_')[0].lower()
            df['politician_id'] = politician_name
            
                   
            df = df.drop(columns=['msg_understand','other_msg_understand'])

            # Add continent based on country
            df['continent'] = df['country'].map(self.continent_mapping)

            # Add politician attributes
            for idx, row in df.iterrows():
                pid = row.get('politician_id', 'unknown')
                if pid in self.politician_info:
                    pdata = self.politician_info[pid]
                    df.loc[idx, 'politician_name'] = pdata['name']
                    df.loc[idx, 'politician_country'] = pdata['country']
                    df.loc[idx, 'politician_continent'] = pdata['continent']
                    df.loc[idx, 'ideology'] = pdata['ideology']
                    df.loc[idx, 'popularity_score'] = pdata['popularity_score']
                    df.loc[idx, 'incumbent_status'] = pdata['incumbent_status']
                    df.loc[idx, 'same_country'] = row['country'] == pdata['country']
                    df.loc[idx, 'same_continent'] = df.loc[idx, 'continent'] == pdata['continent']

            dfs.append(df)

        # Combine all individual DataFrames into one
        combined_df = pd.concat(dfs, ignore_index=True)
        return combined_df
    
    
    def analyze_phase1_baseline_perceptions(self):
            """
            Phase 1: Baseline perceptions of original posters (1-5 scale ratings)
            This establishes baseline perceptions before manipulation
            """
            print(f"\n{'='*80}")
            print("PHASE 1: BASELINE PERCEPTIONS ANALYSIS")
            print(f"{'='*80}")
            print("Phase 1 provides baseline ratings of ORIGINAL posters only")
            print("Used for: Controlling baseline differences, geographical effects, familiarity effects")
            
            if self.phase1_df.empty:
                print("No Phase 1 data available")
                return
            
            # Key traits for RQ1-RQ3
            available_traits = [col for col in key_traits if col in self.phase1_df.columns]
            
            if not available_traits:
                print("Key trait columns not found in Phase 1 data")
                print("Available columns:", list(self.phase1_df.columns))
                return
            
            print(f"Analyzing baseline traits: {available_traits}")
            
            # 1. Overall baseline statistics
            print(f"\n=== BASELINE DESCRIPTIVE STATISTICS ===")
            for trait in available_traits:
                trait_data = self.phase1_df[self.phase1_df[trait] != -99][trait].dropna()
                if len(trait_data) > 0:
                    trait_skew = skew(trait_data)
                    mean = trait_data.mean()
                    median = trait_data.median()
                    sd = trait_data.std()
                    min_val = trait_data.min()
                    max_val = trait_data.max()
                    print(f"{trait.capitalize()}: Mean = {mean:.2f}, Median = {median:.2f}, SD = {sd:.2f}, "
                        f"Range = {min_val:.1f}-{max_val:.1f}, n = {len(trait_data)}, Skewness = {trait_skew:.2f}")
            
            # 2. Differences in perceptions by politician
            if 'politician_name' in self.phase1_df.columns:
                politicians = self.phase1_df['politician_name'].unique()
                politicians = [p for p in politicians if not pd.isna(p)]
                
                if len(politicians) > 1:
                    print(f"\n=== BASELINE DIFFERENCES BY POLITICIAN ===")
                    for trait in available_traits:
                        print(f"\n{trait.capitalize()} by politician:")
                        politician_data = []
                        
                        for politician in politicians:
                            pol_data = self.phase1_df[(self.phase1_df['politician_name'] == politician)
                                                      & (self.phase1_df[trait] != -99)
                                                      ][trait].dropna()
                            if len(pol_data) >= 3:
                                politician_data.append(pol_data)
                                print(f"  {politician}: M = {pol_data.mean():.2f}, SD = {pol_data.std():.2f}, n = {len(pol_data)}")
                        
                        if len(politician_data) >= 2:
                            try:
                                stat, p_val = kruskal(*politician_data)
                                print(f"  Statistical test result: p = {p_val:.3f}")
                                if p_val < 0.05:
                                    print("  There are clear differences in how participants rate this trait for different politicians.")
                                    N = sum(len(p) for p in politician_data)
                                    k = len(politician_data)
                                    epsilon_sq = (stat - k + 1) / (N - k)
                                    print(f"  Effect size (epsilon squared): {epsilon_sq:.3f}")
                                    epsilon_interpretation(epsilon_sq)

                                else:
                                    print("  No meaningful differences in ratings between politicians for this trait.")
                            except Exception as e:
                                print(f"  Error in test: {e}")
            
            # 3. Geographical baseline differences (for RQ4)
            self.analyze_phase1_geographical_baselines(available_traits)
            
            # 4. Familiarity effects on baseline
            self.analyze_phase1_familiarity_effects(available_traits)
            
            # 5. Opinion shift after viewing posters
            self.analyze_phase1_opinion_shift()
            
            self.analyze_phase1_understanding_effects(available_traits)
            
            self.analyze_phase1_political_interest(available_traits)
            

    def analyze_phase1_geographical_baselines(self, traits):
        """
        Analyze geographical differences in baseline perceptions
        Important for RQ4 - do continents differ in baseline perceptions?
        """
        print(f"\n=== GEOGRAPHICAL EFFECT ON PERCEPTION (BASELINE) ===")
        
        if 'continent' not in self.phase1_df.columns:
            print("No continent data available")
            return
        
        continents = self.phase1_df['continent'].value_counts()
        continents = continents[continents >= 3]  # Minimum 3 per continent
        
        if len(continents) < 2:
            print("Insufficient data for continental comparison")
            return
        
        print(f"Comparing continents: {list(continents.index)}")
        
        for trait in traits:
            print(f"\n{trait.capitalize()} overall perception analysis - Participant vs Politician Origin:")
            
            # Get all participant-politician pairs with trait ratings
            trait_data = self.phase1_df[(self.phase1_df[trait].notna())
                                        & (self.phase1_df[trait] != -99)
                                        ].copy()
            
            # Separate same vs different continent participant-politician pairs
            same_continent_pairs = trait_data[trait_data['same_continent'] == True]
            diff_continent_pairs = trait_data[trait_data['same_continent'] == False]
            
            if len(same_continent_pairs) >= 5 and len(diff_continent_pairs) >= 5:
                # Calculate how participants rate politicians from same vs different continents
                same_continent_rating = same_continent_pairs[trait].mean()
                same_continent_std = same_continent_pairs[trait].std()
                same_continent_n = len(same_continent_pairs)
                same_continet_min = same_continent_pairs[trait].min()
                same_continet_max = same_continent_pairs[trait].max()
                
                diff_continent_rating = diff_continent_pairs[trait].mean()
                diff_continent_std = diff_continent_pairs[trait].std()
                diff_continent_n = len(diff_continent_pairs)
                diff_continent_min = diff_continent_pairs[trait].min()
                diff_continent_max = diff_continent_pairs[trait].max()
                
                print(f"  Same continent (participant-politician): M = {same_continent_rating:.2f}, SD = {same_continent_std:.2f}, n = {same_continent_n}, Range = {same_continet_min:.1f}-{same_continet_max:.1f}")
                print(f"  Different continent (participant-politician): M = {diff_continent_rating:.2f}, SD = {diff_continent_std:.2f}, n = {diff_continent_n}, Range = {diff_continent_min:.1f}-{diff_continent_max:.1f}")
        
                
                # Statistical test comparing same vs different continent ratings
                try:
                    stat, p_val = mannwhitneyu(same_continent_pairs[trait].dropna(), 
                                            diff_continent_pairs[trait].dropna(), 
                                            alternative='two-sided')
                    # H₀: There is no difference in ratings between same and different continents.
                    # H₁: There is a difference (but not specifying direction)
                    print(f"  Mann-Whitney U test: U = {stat:.1f}, p = {p_val:.3f}")
                    
                    
                    if p_val < 0.05:
                        if same_continent_rating > diff_continent_rating:
                            print(f"  **Reject H₀:**: Overall participants rate politicians from their own continent as MORE {trait} (M diff = {same_continent_rating - diff_continent_rating:.2f})**")
                        else:
                            print(f"  **Reject H₀: Overall participants rate politicians from their own continent as LESS {trait} (M diff = {abs(same_continent_rating - diff_continent_rating):.2f})**")
                    else:
                        print(f"  **Fail to reject H₀**: No significant overall cross-cultural bias detected for {trait} perception")
                        
                except Exception as e:
                    print(f"  Error in statistical test: {e}")
            
            else:
                print(f"  Insufficient data: Same continent pairs n={len(same_continent_pairs)}, Different continent pairs n={len(diff_continent_pairs)}")
                print(f"  (Minimum n=5 required for each group)")
            
            # Detailed breakdown by specific continent combinations
            print(f"  \nDetailed continent by continent analysis:")
            
            # Group by participant continent
            continents = trait_data['continent'].unique()
            
            for participant_continent in continents:
                    # เช่น ผู้เข้าร่วมจากยุโรป
                    participant_data = trait_data[trait_data['continent'] == participant_continent]
                    
                    if len(participant_data) >= 5:  # Ensure sufficient data
                        print(f"    \n    Participants from {participant_continent}:")
                        
                        for politician_continents in continents:
                            # เช่น นักการเมืองจากยุโรปในข้อมูลผู้เข้าร่วมจากยุโรป หรือ นักการเมืองจากเอเชียในข้อมูลผู้เข้าร่วมจากยุโรป
                            politician_data = participant_data[participant_data['politician_continent'] == politician_continents]
                            
                            if len(politician_data) >= 3:
                                rating = politician_data[trait].mean()
                                n = len(politician_data)
                                relationship = "SAME CONTINENT" if participant_continent == politician_continents else "DIFFERENT CONTINENT"
                                
                                print(f"      → Rate {politician_continents} politicians: M = {rating:.2f}, n = {n} ({relationship})")
                        
                        # Compare same vs different continent for this participant group 
                        same_ratings = participant_data[participant_data['continent'] == participant_data['politician_continent']]
                        diff_ratings = participant_data[participant_data['continent'] != participant_data['politician_continent']]

                        if len(same_ratings) >= 3 and len(diff_ratings) >= 3:
                            try:
                                data1 = same_ratings[trait].dropna() 
                                data2 = diff_ratings[trait].dropna()
                                
                                
                                U, p_val = mannwhitneyu(data1, data2, alternative='two-sided')
                                n1 = len(data1)
                                n2 = len(data2)

                                # Calculate rank-biserial correlation
                                r_rb = 1 - (2 * U) / (n1 * n2)

                                if p_val < 0.05:
                                    if trait in skew_traits:
                                        bias_direction = "higher" if r_rb > 0 else "lower"
                                    else:
                                        bias_direction = 'higher' if data1.mean() > data2.mean() else 'lower'
                                    print(f"      → **{participant_continent} participants gave {bias_direction} {trait} ratings to politicians from their continent (p = {p_val:.3f}, r_rb = {r_rb:.3f})**")        
                            except Exception as e:
                                pass
                        # Note when use man the result go other ways 

              
    def analyze_phase1_familiarity_effects(self, traits):
        """
        Analyze how familiarity affects baseline perceptions
        """
        print(f"\n=== FAMILIARITY EFFECTS ON PERCEPTION (BASELINE) ===")
        
        if 'familiarity' not in self.phase1_df.columns:
            print("No familiarity data available")
            return
        
        familiarity_levels = self.phase1_df['familiarity'].value_counts()
        print(f"Familiarity distribution: {dict(familiarity_levels)}")
        
        for trait in traits:
            print(f"\n{trait.capitalize()} by familiarity:")
            familiarity_data = []
            familiarity_names = []

            means_dict = {}

            for familiarity in familiarity_levels.index:
                if pd.isna(familiarity):
                    continue
                fam_data = self.phase1_df[(self.phase1_df['familiarity'] == familiarity)
                                          & (self.phase1_df[trait] != -99)
                                          ][trait].dropna()
                
                if len(fam_data) >= 3:
                    familiarity_data.append(fam_data)
                    familiarity_names.append(familiarity)
                    means_dict[familiarity] = fam_data.mean()
                    print(f"  {familiarity}: Average rating = {fam_data.mean():.2f} (n = {len(fam_data)})")

            if len(familiarity_data) >= 2:
                try:
                    stat, p_val = kruskal(*familiarity_data)
                    print(f"  Statistical test: p = {p_val:.3f}")
                    if p_val < 0.05:
                        print(f"  Familiarity DOES affect ratings for {trait}.")

                        # Effect size epsilon squared (ε²) for Kruskal-Wallis
                        N = sum(len(group) for group in familiarity_data)
                        k = len(familiarity_data)
                        epsilon_sq = (stat - k + 1) / (N - k)
                        print(f"  Effect size (epsilon squared): {epsilon_sq:.3f}")
                        epsilon_interpretation(epsilon_sq)

                        # Find highest and lowest mean groups (descriptive)
                        sorted_means = sorted(means_dict.items(), key=lambda x: x[1])
                        lowest_group, lowest_mean = sorted_means[0]
                        highest_group, highest_mean = sorted_means[-1]
                        print(f"    People who are '{highest_group}' gave the HIGHEST ratings ({highest_mean:.2f}).")
                        print(f"    People who are '{lowest_group}' gave the LOWEST ratings ({lowest_mean:.2f}).")
                except Exception as e:
                    print(f"  Error: {e}")
                    
    def analyze_phase1_opinion_shift(self):
        opinion_map = {
            "Extremely negative": 1,
            "Somewhat negative": 2,
            "Neutral": 3,
            "Somewhat positive": 4,
            "Extremely positive": 5
        }

        # Map opinions to ordinal values
        df = self.phase1_df.copy()
        df['pre_opinion_num'] = df['pre_opinion'].map(opinion_map)
        df['post_opinion_num'] = df['post_opinion'].map(opinion_map)
        

        # Drop rows with missing values
        paired_df = df.dropna(subset=['pre_opinion_num', 'post_opinion_num'])
        
        print(f"\n=== OPINION SHIFT AFTER VIEWING POSTERS ===")

        # Wilcoxon Signed-Rank test
        if len(paired_df) >= 10:  # Minimum sample size for Wilcoxon
            stat, p_val = wilcoxon(paired_df['pre_opinion_num'], paired_df['post_opinion_num'])
            
            # Calculate matched-pairs rank-biserial correlation
            r_rb = rank_biserial_matched_pairs(paired_df['pre_opinion_num'], paired_df['post_opinion_num'])
            
            print(f"Wilcoxon Signed-Rank test for opinion shift (pre vs post):")
            print(f"  n = {len(paired_df)}")
            print(f"  Statistic = {stat:.2f}, p-value = {p_val:.4f}")
            # These are value skew, so we can't use mean/std
            print(f"  Skewness pre-opinion = {skew(paired_df['pre_opinion_num']):.2f}, Skewness post-opinion = {skew(paired_df['post_opinion_num']):.2f}")
            
            median_pre = paired_df['pre_opinion_num'].median()
            median_post = paired_df['post_opinion_num'].median()
            print(f"  Median pre-opinion = {median_pre:.2f}, Median post-opinion = {median_post:.2f}")
            
            if p_val < 0.05:
                # H₁: There is a consistent shift in opinions after viewing the poster.
                print("  **Significant shift in opinion after viewing the poster**")
                if r_rb > 0:
                    print(f"  Participants viewed the politicians more positively after viewing (r_rb = {r_rb:.3f})")
                elif r_rb < 0:
                    print(f"  Participants viewed the politicians more negatively after viewing (r_rb = {r_rb:.3f})")
                else:
                    print("  Significant test but negligible effect size")
            else:
                # H₀: There is no consistent change in opinions before and after viewing the poster.
                print("  No significant shift in opinion detected.")
        else:
            print("Insufficient paired data for Wilcoxon test (need at least 10 pairs).")
            
    def analyze_phase1_understanding_effects(self, traits):
        """
        Analyze how language understanding and poster meaning affect trait perception.
        Includes post-hoc pairwise tests if significant differences are found.
        """
        print("\n=== UNDERSTANDING EFFECTS ON PERCEPTION ===")

        if 'understand_lang' not in self.phase1_df.columns or 'poster_meaning' not in self.phase1_df.columns:
            print("No understanding data available.")
            return

        binary_mapper = {'Yes': 1, 'No': 0}
        df = self.phase1_df.copy()
        df['understand_lang'] = df['understand_lang'].map(binary_mapper)
        df['poster_meaning'] = df['poster_meaning'].map(binary_mapper)

        group_labels = {
            (1, 1): "Understood BOTH language and poster meaning",
            (1, 0): "Understood ONLY language",
            (0, 1): "Understood ONLY poster meaning",
            (0, 0): "Did NOT understand language NOR poster meaning"
        }

        print("\nParticipant Group Distribution:")
        for (lang, mean), label in group_labels.items():
            count = df[(df['understand_lang'] == lang) & (df['poster_meaning'] == mean)].shape[0]
            print(f"  {label}: {count} participants")

        for trait in traits:
            if trait not in df.columns:
                print(f"\nTrait '{trait}' not found in data.")
                continue

            print(f"\n--- Trait: {trait.capitalize()} ---")
            group_stats = {}
            for (lang, mean), label in group_labels.items():
                data = df[(df['understand_lang'] == lang) & (df['poster_meaning'] == mean)][trait].dropna()
                if len(data) > 0:
                    group_stats[label] = data
                    print(f"  {label}: Mean={data.mean():.2f}, SD={data.std():.2f}, n={len(data)}")

            valid_groups = [data for data in group_stats.values() if len(data) >= 3]
            if len(valid_groups) >= 2:
                try:
                    stat, p_val = kruskal(*valid_groups)
                    print(f"  Kruskal-Wallis test: H={stat:.2f}, p={p_val:.3f}")
                    if p_val < 0.05:
                        print("  Significant differences found between understanding groups.")

                        # Calculate epsilon squared for overall effect size
                        N = sum(len(g) for g in valid_groups)
                        k = len(valid_groups)
                        epsilon_sq = (stat - k + 1) / (N - k)
                        print(f"  Effect size (epsilon squared): {epsilon_sq:.3f}")
                        epsilon_interpretation(epsilon_sq)

                        # Post-hoc pairwise Mann-Whitney U tests with rank-biserial effect size
                        labels = list(group_stats.keys())
                        for i in range(len(labels)):
                            for j in range(i+1, len(labels)):
                                data1 = group_stats[labels[i]]
                                data2 = group_stats[labels[j]]
                                n1, n2 = len(data1), len(data2)

                                if n1 >= 3 and n2 >= 3:
                                    stat_u, p_u = mannwhitneyu(data1, data2, alternative='two-sided')

                                    # Calculate rank-biserial correlation
                                    r_rb = 1 - (2 * stat_u) / (n1 * n2)

                                    if p_u < 0.05:
                                        if trait in skew_traits:
                                            direction = "higher" if r_rb > 0 else "lower"
                                        else:
                                            direction = 'higher' if data1.mean() > data2.mean() else 'lower'
                                        print(
                                            f"Participants who {labels[i]} rated {trait} {direction} than those who '{labels[j]}' "
                                            f"(rank-biserial r = {r_rb:.3f}, p = {p_u:.3f})"
                                        )
                    else:
                        print(" No significant differences between understanding groups.")
                except Exception as e:
                    print(f"  Error in Kruskal-Wallis test: {e}")
            else:
                print("  Not enough data for statistical test (need at least 2 groups with n>=3).")

                
    def analyze_phase1_political_interest(self, traits):
        """
        Analyze how different levels of political engagement affect trait ratings.
        For each trait, runs Kruskal-Wallis test and reports which engagement group rates higher/lower.
        """
        print(f"\n{'='*80}")
        print("=== POLITICAL ENGAGEMENT EFFECTS ON TRAIT PERCEPTION ===")
        print(f"{'='*80}")

        if 'political_engagement' not in self.phase1_df.columns:
            print("No political engagement data available.")
            return

        # Only use valid engagement responses
        engagement_levels = self.phase1_df['political_engagement'].value_counts().index.tolist()
        print(f"Political engagement groups: {engagement_levels}")

        for trait in traits:
            print(f"\nTrait: {trait.capitalize()}")
            trait_data = []
            group_names = []
            means_dict = {}

            for level in engagement_levels:
                group = self.phase1_df[
                    (self.phase1_df['political_engagement'] == level) &
                    (self.phase1_df[trait] != -99)
                ][trait].dropna()
                if len(group) >= 3:
                    trait_data.append(group)
                    group_names.append(level)
                    means_dict[level] = group.mean()
                    print(f"  {level}: Mean = {group.mean():.2f}, SD = {group.std():.2f}, n = {len(group)}")

            if len(trait_data) >= 2:
                try:
                    stat, p_val = kruskal(*trait_data)
                    print(f"  Kruskal-Wallis test: H = {stat:.2f}, p = {p_val:.3f}")
                    if p_val < 0.05:
                        print("  Significant differences between engagement groups.")
                        # Effect size
                        N = sum(len(g) for g in trait_data)
                        k = len(trait_data)
                        epsilon_sq = (stat - k + 1) / (N - k)
                        print(f"  Effect size (epsilon squared): {epsilon_sq:.3f}")
                        epsilon_interpretation(epsilon_sq)

                        # Direction: which group rates highest/lowest
                        sorted_means = sorted(means_dict.items(), key=lambda x: x[1])
                        lowest_group, lowest_mean = sorted_means[0]
                        highest_group, highest_mean = sorted_means[-1]
                        print(f"    '{highest_group}' engagement group gave the HIGHEST ratings ({highest_mean:.2f}).")
                        print(f"    '{lowest_group}' engagement group gave the LOWEST ratings ({lowest_mean:.2f}).")
                    else:
                        print("  No significant differences between engagement groups.")
                except Exception as e:
                    print(f"  Error in Kruskal-Wallis test: {e}")
            else:
                print("  Not enough data for statistical test (need at least 2 groups with n>=3).")
                
                
    def run_research_questions_analysis(self):
        """
        Main analysis pipeline specifically designed to answer RQ1-RQ4
        """
        # Phase 1: Establish baselines and control variables
        self.analyze_phase1_baseline_perceptions()

# %%
phase1_data = [
    'phase1_data/lula_phase1_data.csv',
    'phase1_data/masisi_phase1_data.csv',
    'phase1_data/lee_phase1_data.csv',
    'phase1_data/ruto_phase1_data.csv',
    'phase1_data/yoon_phase1_data.csv',
    'phase1_data/kenyatta_phase1_data.csv',
    'phase1_data/jacinda_phase1_data.csv',
    'phase1_data/albanese_phase1_data.csv',
    'phase1_data/modi_phase1_data.csv',
    'phase1_data/harper_phase1_data.csv',
    'phase1_data/morrison_phase1_data.csv',
    'phase1_data/friedrich_phase1_data.csv',
    'phase1_data/sunak_phase1_data.csv',
    'phase1_data/boko_phase1_data.csv',
    'phase1_data/prayut_phase1_data.csv',
    'phase1_data/trump_phase1_data.csv',
    'phase1_data/luxon_phase1_data.csv',
    'phase1_data/biden_phase1_data.csv',
    'phase1_data/trudeau_phase1_data.csv',
    'phase1_data/starmer_phase1_data.csv',
    'phase1_data/paetongtarn_phase1_data.csv',
    'phase1_data/bolsonaro_phase1_data.csv',
    'phase1_data/olaf_phase1_data.csv',
    'phase1_data/singh_phase1_data.csv',
]


analyzer = Phase1Analyser(phase1_data)

# Run the recommended analysis pipeline
analyzer.run_research_questions_analysis()
# Out:
# ================================================================================
# PHASE 1: BASELINE PERCEPTIONS ANALYSIS
# ================================================================================
# Phase 1 provides baseline ratings of ORIGINAL posters only
# Used for: Controlling baseline differences, geographical effects, familiarity effects
# Analyzing baseline traits: ['competence', 'likable', 'trustworthy', 'approachable', 'charismatic', 'aggressive', 'friendly', 'professional', 'visually_appealing', 'professionally_designed', 'aggressive_poster', 'inspirational', 'manipulative', 'boring', 'misleading', 'match_pol_comm', 'credible_typo_color', 'background', 'typo_attention', 'support', 'interested_in']
#
# === BASELINE DESCRIPTIVE STATISTICS ===
# Competence: Mean = 3.17, Median = 3.00, SD = 1.14, Range = 1.0-5.0, n = 314, Skewness = -0.19
# Likable: Mean = 3.08, Median = 3.00, SD = 1.21, Range = 1.0-5.0, n = 314, Skewness = -0.17
# Trustworthy: Mean = 2.90, Median = 3.00, SD = 1.17, Range = 1.0-5.0, n = 315, Skewness = -0.04
# Approachable: Mean = 3.05, Median = 3.00, SD = 1.27, Range = 1.0-5.0, n = 315, Skewness = -0.07
# Charismatic: Mean = 2.99, Median = 3.00, SD = 1.17, Range = 1.0-5.0, n = 313, Skewness = -0.12
# Aggressive: Mean = 2.25, Median = 2.00, SD = 1.26, Range = 0.0-5.0, n = 313, Skewness = 0.67
# Friendly: Mean = 3.06, Median = 3.00, SD = 1.24, Range = 1.0-5.0, n = 314, Skewness = -0.17
# Professional: Mean = 3.40, Median = 3.00, SD = 1.18, Range = 1.0-5.0, n = 315, Skewness = -0.41
# Visually_appealing: Mean = 3.09, Median = 3.00, SD = 1.26, Range = 1.0-5.0, n = 314, Skewness = -0.20
# Professionally_designed: Mean = 3.16, Median = 3.00, SD = 1.28, Range = 1.0-5.0, n = 314, Skewness = -0.14
# Aggressive_poster: Mean = 2.04, Median = 2.00, SD = 1.27, Range = 0.0-5.0, n = 313, Skewness = 0.92
# Inspirational: Mean = 2.28, Median = 2.00, SD = 1.19, Range = 1.0-5.0, n = 314, Skewness = 0.64
# Manipulative: Mean = 2.05, Median = 2.00, SD = 1.25, Range = 0.0-5.0, n = 312, Skewness = 0.92
# Boring: Mean = 2.74, Median = 3.00, SD = 1.32, Range = 0.0-5.0, n = 314, Skewness = 0.19
# Misleading: Mean = 1.86, Median = 1.00, SD = 1.14, Range = 0.0-5.0, n = 311, Skewness = 1.24
# Match_pol_comm: Mean = 3.21, Median = 3.00, SD = 1.07, Range = 1.0-5.0, n = 313, Skewness = -0.34
# Credible_typo_color: Mean = 3.28, Median = 4.00, SD = 1.06, Range = 1.0-5.0, n = 316, Skewness = -0.45
# Background: Mean = 3.22, Median = 3.00, SD = 1.11, Range = 1.0-5.0, n = 316, Skewness = -0.34
# Typo_attention: Mean = 3.15, Median = 3.00, SD = 1.11, Range = 1.0-5.0, n = 316, Skewness = -0.18
# Support: Mean = 2.61, Median = 3.00, SD = 1.06, Range = 1.0-5.0, n = 316, Skewness = 0.07
# Interested_in: Mean = 2.75, Median = 3.00, SD = 1.14, Range = 1.0-5.0, n = 317, Skewness = 0.04
#
# === BASELINE DIFFERENCES BY POLITICIAN ===
#
# Competence by politician:
#   Luiz Inácio Lula da Silva: M = 2.45, SD = 0.69, n = 11
#   Mokgweetsi Masisi: M = 3.23, SD = 1.01, n = 13
#   Lee Jae-myung: M = 3.69, SD = 0.95, n = 16
#   William Ruto: M = 3.88, SD = 0.89, n = 16
#   Yoon Suk Yeol: M = 2.56, SD = 1.09, n = 16
#   Uhuru Kenyatta: M = 2.83, SD = 0.75, n = 6
#   Jacinda Ardern: M = 3.79, SD = 1.05, n = 14
#   Anthony Albanese: M = 3.83, SD = 0.75, n = 6
#   Narendra Modi: M = 3.20, SD = 1.48, n = 10
#   Stephen Harper: M = 2.75, SD = 1.14, n = 12
#   Scott Morrison: M = 2.89, SD = 1.02, n = 18
#   Friedrich Merz: M = 3.69, SD = 1.35, n = 16
#   Rishi Sunak: M = 3.14, SD = 1.07, n = 7
#   Duma Boko: M = 3.67, SD = 1.15, n = 12
#   Prayut Chan-o-cha: M = 3.07, SD = 0.96, n = 15
#   Donald Trump: M = 2.61, SD = 1.46, n = 18
#   Christopher Luxon: M = 3.00, SD = 1.13, n = 12
#   Joe Biden: M = 2.67, SD = 1.23, n = 15
#   Justin Trudeau: M = 3.25, SD = 0.97, n = 12
#   Keir Starmer: M = 3.27, SD = 0.70, n = 15
#   Paetongtarn Shinawatra: M = 3.73, SD = 0.79, n = 11
#   Jair Bolsonaro: M = 1.92, SD = 0.86, n = 13
#   Olaf Scholz: M = 3.62, SD = 1.12, n = 13
#   Manmohan Singh: M = 3.47, SD = 1.01, n = 17
#   Statistical test result: p = 0.000
#   There are clear differences in how participants rate this trait for different politicians.
#   Effect size (epsilon squared): 0.135
# Medium effect size (moderate practical impact).
#
# Likable by politician:
#   Luiz Inácio Lula da Silva: M = 2.36, SD = 0.81, n = 11
#   Mokgweetsi Masisi: M = 3.38, SD = 1.19, n = 13
#   Lee Jae-myung: M = 3.69, SD = 0.95, n = 16
#   William Ruto: M = 4.38, SD = 0.72, n = 16
#   Yoon Suk Yeol: M = 2.12, SD = 1.26, n = 16
#   Uhuru Kenyatta: M = 3.17, SD = 0.98, n = 6
#   Jacinda Ardern: M = 3.93, SD = 0.92, n = 14
#   Anthony Albanese: M = 3.17, SD = 1.17, n = 6
#   Narendra Modi: M = 3.70, SD = 1.34, n = 10
#   Stephen Harper: M = 2.75, SD = 1.36, n = 12
#   Scott Morrison: M = 2.33, SD = 1.14, n = 18
#   Friedrich Merz: M = 3.25, SD = 1.06, n = 16
#   Rishi Sunak: M = 3.29, SD = 1.11, n = 7
#   Duma Boko: M = 3.42, SD = 1.00, n = 12
#   Prayut Chan-o-cha: M = 3.47, SD = 0.99, n = 15
#   Donald Trump: M = 1.72, SD = 0.89, n = 18
#   Christopher Luxon: M = 3.00, SD = 0.85, n = 12
#   Joe Biden: M = 3.13, SD = 1.25, n = 15
#   Justin Trudeau: M = 3.50, SD = 0.80, n = 12
#   Keir Starmer: M = 2.33, SD = 0.62, n = 15
#   Paetongtarn Shinawatra: M = 3.82, SD = 0.98, n = 11
#   Jair Bolsonaro: M = 2.46, SD = 1.39, n = 13
#   Olaf Scholz: M = 2.69, SD = 0.75, n = 13
#   Manmohan Singh: M = 3.65, SD = 1.06, n = 17
#   Statistical test result: p = 0.000
#   There are clear differences in how participants rate this trait for different politicians.
#   Effect size (epsilon squared): 0.263
# Large effect size (substantial practical impact).
#
# Trustworthy by politician:
#   Luiz Inácio Lula da Silva: M = 2.09, SD = 0.70, n = 11
#   Mokgweetsi Masisi: M = 2.69, SD = 0.95, n = 13
#   Lee Jae-myung: M = 3.19, SD = 0.66, n = 16
#   William Ruto: M = 3.62, SD = 0.81, n = 16
#   Yoon Suk Yeol: M = 2.19, SD = 1.42, n = 16
#   Uhuru Kenyatta: M = 2.50, SD = 0.55, n = 6
#   Jacinda Ardern: M = 3.80, SD = 1.26, n = 15
#   Anthony Albanese: M = 3.67, SD = 0.52, n = 6
#   Narendra Modi: M = 3.20, SD = 1.14, n = 10
#   Stephen Harper: M = 2.83, SD = 1.11, n = 12
#   Scott Morrison: M = 2.06, SD = 0.80, n = 18
#   Friedrich Merz: M = 3.25, SD = 1.13, n = 16
#   Rishi Sunak: M = 3.43, SD = 0.53, n = 7
#   Duma Boko: M = 3.33, SD = 1.07, n = 12
#   Prayut Chan-o-cha: M = 3.33, SD = 1.23, n = 15
#   Donald Trump: M = 1.89, SD = 0.96, n = 18
#   Christopher Luxon: M = 3.00, SD = 1.28, n = 12
#   Joe Biden: M = 3.07, SD = 1.10, n = 15
#   Justin Trudeau: M = 3.00, SD = 1.13, n = 12
#   Keir Starmer: M = 2.53, SD = 1.25, n = 15
#   Paetongtarn Shinawatra: M = 3.82, SD = 0.87, n = 11
#   Jair Bolsonaro: M = 1.85, SD = 0.90, n = 13
#   Olaf Scholz: M = 2.85, SD = 1.07, n = 13
#   Manmohan Singh: M = 3.35, SD = 1.06, n = 17
#   Statistical test result: p = 0.000
#   There are clear differences in how participants rate this trait for different politicians.
#   Effect size (epsilon squared): 0.214
# Large effect size (substantial practical impact).
#
# Approachable by politician:
#   Luiz Inácio Lula da Silva: M = 2.55, SD = 0.93, n = 11
#   Mokgweetsi Masisi: M = 3.46, SD = 1.20, n = 13
#   Lee Jae-myung: M = 3.69, SD = 1.08, n = 16
#   William Ruto: M = 3.69, SD = 1.14, n = 16
#   Yoon Suk Yeol: M = 2.50, SD = 1.37, n = 16
#   Uhuru Kenyatta: M = 2.67, SD = 0.82, n = 6
#   Jacinda Ardern: M = 3.93, SD = 1.16, n = 15
#   Anthony Albanese: M = 3.00, SD = 1.26, n = 6
#   Narendra Modi: M = 3.40, SD = 1.35, n = 10
#   Stephen Harper: M = 2.67, SD = 0.98, n = 12
#   Scott Morrison: M = 2.33, SD = 1.03, n = 18
#   Friedrich Merz: M = 3.25, SD = 1.34, n = 16
#   Rishi Sunak: M = 2.71, SD = 1.25, n = 7
#   Duma Boko: M = 3.58, SD = 1.00, n = 12
#   Prayut Chan-o-cha: M = 3.67, SD = 0.98, n = 15
#   Donald Trump: M = 1.72, SD = 0.89, n = 18
#   Christopher Luxon: M = 3.58, SD = 1.16, n = 12
#   Joe Biden: M = 3.20, SD = 1.26, n = 15
#   Justin Trudeau: M = 3.50, SD = 1.31, n = 12
#   Keir Starmer: M = 2.20, SD = 1.01, n = 15
#   Paetongtarn Shinawatra: M = 3.64, SD = 1.03, n = 11
#   Jair Bolsonaro: M = 2.31, SD = 1.38, n = 13
#   Olaf Scholz: M = 2.38, SD = 1.12, n = 13
#   Manmohan Singh: M = 3.59, SD = 1.12, n = 17
#   Statistical test result: p = 0.000
#   There are clear differences in how participants rate this trait for different politicians.
#   Effect size (epsilon squared): 0.197
# Large effect size (substantial practical impact).
#
# Charismatic by politician:
#   Luiz Inácio Lula da Silva: M = 2.45, SD = 0.69, n = 11
#   Mokgweetsi Masisi: M = 3.00, SD = 1.22, n = 13
#   Lee Jae-myung: M = 3.38, SD = 1.02, n = 16
#   William Ruto: M = 3.69, SD = 1.14, n = 16
#   Yoon Suk Yeol: M = 2.50, SD = 1.26, n = 16
#   Uhuru Kenyatta: M = 2.67, SD = 1.03, n = 6
#   Jacinda Ardern: M = 3.67, SD = 1.23, n = 15
#   Anthony Albanese: M = 3.17, SD = 1.17, n = 6
#   Narendra Modi: M = 3.40, SD = 1.35, n = 10
#   Stephen Harper: M = 2.75, SD = 1.06, n = 12
#   Scott Morrison: M = 2.22, SD = 0.81, n = 18
#   Friedrich Merz: M = 3.25, SD = 1.13, n = 16
#   Rishi Sunak: M = 3.14, SD = 1.21, n = 7
#   Duma Boko: M = 3.18, SD = 1.25, n = 11
#   Prayut Chan-o-cha: M = 3.13, SD = 0.92, n = 15
#   Donald Trump: M = 2.44, SD = 1.29, n = 18
#   Christopher Luxon: M = 3.25, SD = 0.97, n = 12
#   Joe Biden: M = 2.73, SD = 1.10, n = 15
#   Justin Trudeau: M = 3.50, SD = 1.00, n = 12
#   Keir Starmer: M = 2.29, SD = 1.07, n = 14
#   Paetongtarn Shinawatra: M = 3.82, SD = 0.75, n = 11
#   Jair Bolsonaro: M = 2.62, SD = 1.33, n = 13
#   Olaf Scholz: M = 2.69, SD = 1.25, n = 13
#   Manmohan Singh: M = 3.29, SD = 1.16, n = 17
#   Statistical test result: p = 0.001
#   There are clear differences in how participants rate this trait for different politicians.
#   Effect size (epsilon squared): 0.097
# Medium effect size (moderate practical impact).
#
# Aggressive by politician:
#   Luiz Inácio Lula da Silva: M = 1.82, SD = 1.17, n = 11
#   Mokgweetsi Masisi: M = 2.15, SD = 1.14, n = 13
#   Lee Jae-myung: M = 1.81, SD = 0.98, n = 16
#   William Ruto: M = 1.94, SD = 0.93, n = 16
#   Yoon Suk Yeol: M = 2.12, SD = 1.31, n = 16
#   Uhuru Kenyatta: M = 2.17, SD = 0.98, n = 6
#   Jacinda Ardern: M = 2.33, SD = 1.35, n = 15
#   Anthony Albanese: M = 2.83, SD = 1.33, n = 6
#   Narendra Modi: M = 1.80, SD = 1.03, n = 10
#   Stephen Harper: M = 1.83, SD = 0.83, n = 12
#   Scott Morrison: M = 2.28, SD = 1.27, n = 18
#   Friedrich Merz: M = 2.12, SD = 1.26, n = 16
#   Rishi Sunak: M = 1.57, SD = 0.98, n = 7
#   Duma Boko: M = 1.92, SD = 1.16, n = 12
#   Prayut Chan-o-cha: M = 2.00, SD = 1.25, n = 15
#   Donald Trump: M = 3.89, SD = 0.96, n = 18
#   Christopher Luxon: M = 2.67, SD = 1.61, n = 12
#   Joe Biden: M = 1.64, SD = 0.93, n = 14
#   Justin Trudeau: M = 2.33, SD = 1.07, n = 12
#   Keir Starmer: M = 2.93, SD = 1.44, n = 15
#   Paetongtarn Shinawatra: M = 1.55, SD = 0.93, n = 11
#   Jair Bolsonaro: M = 2.58, SD = 1.31, n = 12
#   Olaf Scholz: M = 3.15, SD = 1.14, n = 13
#   Manmohan Singh: M = 1.82, SD = 1.19, n = 17
#   Statistical test result: p = 0.000
#   There are clear differences in how participants rate this trait for different politicians.
#   Effect size (epsilon squared): 0.124
# Medium effect size (moderate practical impact).
#
# Friendly by politician:
#   Luiz Inácio Lula da Silva: M = 2.45, SD = 0.93, n = 11
#   Mokgweetsi Masisi: M = 3.08, SD = 1.12, n = 13
#   Lee Jae-myung: M = 3.69, SD = 0.87, n = 16
#   William Ruto: M = 3.94, SD = 0.68, n = 16
#   Yoon Suk Yeol: M = 2.69, SD = 1.49, n = 16
#   Uhuru Kenyatta: M = 3.00, SD = 0.89, n = 6
#   Jacinda Ardern: M = 3.60, SD = 1.30, n = 15
#   Anthony Albanese: M = 3.17, SD = 1.33, n = 6
#   Narendra Modi: M = 3.60, SD = 1.35, n = 10
#   Stephen Harper: M = 3.00, SD = 1.48, n = 12
#   Scott Morrison: M = 2.67, SD = 1.37, n = 18
#   Friedrich Merz: M = 3.38, SD = 1.09, n = 16
#   Rishi Sunak: M = 3.57, SD = 1.13, n = 7
#   Duma Boko: M = 3.25, SD = 0.97, n = 12
#   Prayut Chan-o-cha: M = 3.67, SD = 0.98, n = 15
#   Donald Trump: M = 1.39, SD = 0.78, n = 18
#   Christopher Luxon: M = 3.00, SD = 1.21, n = 12
#   Joe Biden: M = 3.00, SD = 1.13, n = 15
#   Justin Trudeau: M = 3.08, SD = 0.79, n = 12
#   Keir Starmer: M = 2.14, SD = 1.03, n = 14
#   Paetongtarn Shinawatra: M = 3.64, SD = 0.92, n = 11
#   Jair Bolsonaro: M = 3.08, SD = 1.32, n = 13
#   Olaf Scholz: M = 2.23, SD = 0.73, n = 13
#   Manmohan Singh: M = 3.71, SD = 1.16, n = 17
#   Statistical test result: p = 0.000
#   There are clear differences in how participants rate this trait for different politicians.
#   Effect size (epsilon squared): 0.195
# Large effect size (substantial practical impact).
#
# Professional by politician:
#   Luiz Inácio Lula da Silva: M = 2.27, SD = 0.79, n = 11
#   Mokgweetsi Masisi: M = 3.00, SD = 1.08, n = 13
#   Lee Jae-myung: M = 4.25, SD = 0.77, n = 16
#   William Ruto: M = 3.69, SD = 1.01, n = 16
#   Yoon Suk Yeol: M = 3.31, SD = 1.40, n = 16
#   Uhuru Kenyatta: M = 2.83, SD = 1.33, n = 6
#   Jacinda Ardern: M = 3.80, SD = 0.94, n = 15
#   Anthony Albanese: M = 3.83, SD = 0.41, n = 6
#   Narendra Modi: M = 3.40, SD = 1.43, n = 10
#   Stephen Harper: M = 3.50, SD = 1.09, n = 12
#   Scott Morrison: M = 3.28, SD = 0.89, n = 18
#   Friedrich Merz: M = 3.81, SD = 1.22, n = 16
#   Rishi Sunak: M = 3.00, SD = 0.58, n = 7
#   Duma Boko: M = 4.17, SD = 0.83, n = 12
#   Prayut Chan-o-cha: M = 3.20, SD = 1.15, n = 15
#   Donald Trump: M = 2.72, SD = 1.36, n = 18
#   Christopher Luxon: M = 3.50, SD = 1.31, n = 12
#   Joe Biden: M = 3.40, SD = 1.18, n = 15
#   Justin Trudeau: M = 3.33, SD = 0.65, n = 12
#   Keir Starmer: M = 3.80, SD = 1.01, n = 15
#   Paetongtarn Shinawatra: M = 4.27, SD = 0.79, n = 11
#   Jair Bolsonaro: M = 1.69, SD = 0.95, n = 13
#   Olaf Scholz: M = 3.54, SD = 1.05, n = 13
#   Manmohan Singh: M = 3.53, SD = 1.12, n = 17
#   Statistical test result: p = 0.000
#   There are clear differences in how participants rate this trait for different politicians.
#   Effect size (epsilon squared): 0.163
# Large effect size (substantial practical impact).
#
# Visually_appealing by politician:
#   Luiz Inácio Lula da Silva: M = 2.64, SD = 1.21, n = 11
#   Mokgweetsi Masisi: M = 2.46, SD = 1.13, n = 13
#   Lee Jae-myung: M = 3.69, SD = 1.08, n = 16
#   William Ruto: M = 3.44, SD = 1.09, n = 16
#   Yoon Suk Yeol: M = 3.19, SD = 1.56, n = 16
#   Uhuru Kenyatta: M = 2.17, SD = 1.47, n = 6
#   Jacinda Ardern: M = 3.40, SD = 1.12, n = 15
#   Anthony Albanese: M = 2.33, SD = 0.52, n = 6
#   Narendra Modi: M = 3.60, SD = 1.35, n = 10
#   Stephen Harper: M = 2.67, SD = 1.44, n = 12
#   Scott Morrison: M = 2.83, SD = 1.25, n = 18
#   Friedrich Merz: M = 3.31, SD = 1.30, n = 16
#   Rishi Sunak: M = 2.71, SD = 1.60, n = 7
#   Duma Boko: M = 3.50, SD = 0.90, n = 12
#   Prayut Chan-o-cha: M = 2.73, SD = 1.16, n = 15
#   Donald Trump: M = 3.33, SD = 1.19, n = 18
#   Christopher Luxon: M = 2.50, SD = 1.00, n = 12
#   Joe Biden: M = 3.13, SD = 1.13, n = 15
#   Justin Trudeau: M = 3.83, SD = 0.83, n = 12
#   Keir Starmer: M = 2.60, SD = 1.30, n = 15
#   Paetongtarn Shinawatra: M = 3.09, SD = 0.94, n = 11
#   Jair Bolsonaro: M = 3.00, SD = 1.41, n = 13
#   Olaf Scholz: M = 3.42, SD = 1.56, n = 12
#   Manmohan Singh: M = 3.24, SD = 1.44, n = 17
#   Statistical test result: p = 0.053
#   No meaningful differences in ratings between politicians for this trait.
#
# Professionally_designed by politician:
#   Luiz Inácio Lula da Silva: M = 2.00, SD = 0.77, n = 11
#   Mokgweetsi Masisi: M = 2.54, SD = 1.20, n = 13
#   Lee Jae-myung: M = 3.94, SD = 0.85, n = 16
#   William Ruto: M = 2.88, SD = 1.41, n = 16
#   Yoon Suk Yeol: M = 3.62, SD = 1.45, n = 16
#   Uhuru Kenyatta: M = 2.00, SD = 1.26, n = 6
#   Jacinda Ardern: M = 3.73, SD = 1.10, n = 15
#   Anthony Albanese: M = 2.50, SD = 1.38, n = 6
#   Narendra Modi: M = 3.30, SD = 1.42, n = 10
#   Stephen Harper: M = 3.25, SD = 1.22, n = 12
#   Scott Morrison: M = 3.33, SD = 1.14, n = 18
#   Friedrich Merz: M = 3.75, SD = 1.34, n = 16
#   Rishi Sunak: M = 2.86, SD = 1.57, n = 7
#   Duma Boko: M = 3.42, SD = 1.00, n = 12
#   Prayut Chan-o-cha: M = 3.13, SD = 1.25, n = 15
#   Donald Trump: M = 3.22, SD = 1.40, n = 18
#   Christopher Luxon: M = 3.00, SD = 1.13, n = 12
#   Joe Biden: M = 2.87, SD = 0.99, n = 15
#   Justin Trudeau: M = 4.08, SD = 1.00, n = 12
#   Keir Starmer: M = 2.67, SD = 1.23, n = 15
#   Paetongtarn Shinawatra: M = 2.91, SD = 0.83, n = 11
#   Jair Bolsonaro: M = 2.46, SD = 1.45, n = 13
#   Olaf Scholz: M = 4.00, SD = 0.95, n = 12
#   Manmohan Singh: M = 2.94, SD = 1.25, n = 17
#   Statistical test result: p = 0.000
#   There are clear differences in how participants rate this trait for different politicians.
#   Effect size (epsilon squared): 0.113
# Medium effect size (moderate practical impact).
#
# Aggressive_poster by politician:
#   Luiz Inácio Lula da Silva: M = 1.64, SD = 1.03, n = 11
#   Mokgweetsi Masisi: M = 2.62, SD = 1.19, n = 13
#   Lee Jae-myung: M = 1.75, SD = 1.48, n = 16
#   William Ruto: M = 1.88, SD = 0.96, n = 16
#   Yoon Suk Yeol: M = 1.88, SD = 1.20, n = 16
#   Uhuru Kenyatta: M = 2.17, SD = 1.17, n = 6
#   Jacinda Ardern: M = 1.40, SD = 0.83, n = 15
#   Anthony Albanese: M = 2.50, SD = 1.38, n = 6
#   Narendra Modi: M = 1.90, SD = 1.29, n = 10
#   Stephen Harper: M = 1.50, SD = 0.90, n = 12
#   Scott Morrison: M = 2.00, SD = 1.24, n = 18
#   Friedrich Merz: M = 1.56, SD = 1.03, n = 16
#   Rishi Sunak: M = 1.43, SD = 1.13, n = 7
#   Duma Boko: M = 1.83, SD = 1.19, n = 12
#   Prayut Chan-o-cha: M = 1.40, SD = 0.74, n = 15
#   Donald Trump: M = 3.11, SD = 1.41, n = 18
#   Christopher Luxon: M = 2.33, SD = 1.23, n = 12
#   Joe Biden: M = 1.50, SD = 1.16, n = 14
#   Justin Trudeau: M = 2.83, SD = 1.40, n = 12
#   Keir Starmer: M = 2.73, SD = 1.22, n = 15
#   Paetongtarn Shinawatra: M = 1.55, SD = 0.93, n = 11
#   Jair Bolsonaro: M = 1.92, SD = 1.32, n = 13
#   Olaf Scholz: M = 3.67, SD = 1.15, n = 12
#   Manmohan Singh: M = 1.82, SD = 1.19, n = 17
#   Statistical test result: p = 0.000
#   There are clear differences in how participants rate this trait for different politicians.
#   Effect size (epsilon squared): 0.156
# Large effect size (substantial practical impact).
#
# Inspirational by politician:
#   Luiz Inácio Lula da Silva: M = 1.64, SD = 0.67, n = 11
#   Mokgweetsi Masisi: M = 2.46, SD = 1.05, n = 13
#   Lee Jae-myung: M = 2.19, SD = 0.98, n = 16
#   William Ruto: M = 2.88, SD = 1.02, n = 16
#   Yoon Suk Yeol: M = 1.69, SD = 1.20, n = 16
#   Uhuru Kenyatta: M = 2.50, SD = 1.76, n = 6
#   Jacinda Ardern: M = 2.33, SD = 0.98, n = 15
#   Anthony Albanese: M = 2.17, SD = 1.60, n = 6
#   Narendra Modi: M = 3.50, SD = 1.51, n = 10
#   Stephen Harper: M = 1.75, SD = 1.06, n = 12
#   Scott Morrison: M = 2.06, SD = 0.80, n = 18
#   Friedrich Merz: M = 2.69, SD = 1.20, n = 16
#   Rishi Sunak: M = 2.71, SD = 1.50, n = 7
#   Duma Boko: M = 2.67, SD = 1.15, n = 12
#   Prayut Chan-o-cha: M = 1.93, SD = 1.10, n = 15
#   Donald Trump: M = 2.17, SD = 1.20, n = 18
#   Christopher Luxon: M = 2.33, SD = 0.98, n = 12
#   Joe Biden: M = 2.47, SD = 1.30, n = 15
#   Justin Trudeau: M = 2.50, SD = 1.24, n = 12
#   Keir Starmer: M = 1.93, SD = 1.33, n = 15
#   Paetongtarn Shinawatra: M = 2.36, SD = 1.03, n = 11
#   Jair Bolsonaro: M = 2.00, SD = 1.29, n = 13
#   Olaf Scholz: M = 2.67, SD = 1.37, n = 12
#   Manmohan Singh: M = 1.94, SD = 1.14, n = 17
#   Statistical test result: p = 0.034
#   There are clear differences in how participants rate this trait for different politicians.
#   Effect size (epsilon squared): 0.047
# Small effect size (small practical impact).
#
# Manipulative by politician:
#   Luiz Inácio Lula da Silva: M = 1.36, SD = 0.67, n = 11
#   Mokgweetsi Masisi: M = 2.15, SD = 1.41, n = 13
#   Lee Jae-myung: M = 1.75, SD = 1.13, n = 16
#   William Ruto: M = 1.62, SD = 0.96, n = 16
#   Yoon Suk Yeol: M = 1.69, SD = 1.20, n = 16
#   Uhuru Kenyatta: M = 2.17, SD = 1.60, n = 6
#   Jacinda Ardern: M = 1.93, SD = 1.22, n = 15
#   Anthony Albanese: M = 2.50, SD = 1.22, n = 6
#   Narendra Modi: M = 2.80, SD = 1.03, n = 10
#   Stephen Harper: M = 1.50, SD = 0.67, n = 12
#   Scott Morrison: M = 1.94, SD = 1.21, n = 18
#   Friedrich Merz: M = 1.81, SD = 1.38, n = 16
#   Rishi Sunak: M = 2.00, SD = 0.82, n = 7
#   Duma Boko: M = 2.17, SD = 1.34, n = 12
#   Prayut Chan-o-cha: M = 1.67, SD = 1.11, n = 15
#   Donald Trump: M = 2.78, SD = 1.31, n = 18
#   Christopher Luxon: M = 2.50, SD = 1.24, n = 12
#   Joe Biden: M = 2.50, SD = 1.74, n = 14
#   Justin Trudeau: M = 2.33, SD = 0.89, n = 12
#   Keir Starmer: M = 1.93, SD = 1.00, n = 14
#   Paetongtarn Shinawatra: M = 1.36, SD = 0.67, n = 11
#   Jair Bolsonaro: M = 2.54, SD = 1.66, n = 13
#   Olaf Scholz: M = 2.83, SD = 1.40, n = 12
#   Manmohan Singh: M = 1.82, SD = 1.33, n = 17
#   Statistical test result: p = 0.013
#   There are clear differences in how participants rate this trait for different politicians.
#   Effect size (epsilon squared): 0.061
# Medium effect size (moderate practical impact).
#
# Boring by politician:
#   Luiz Inácio Lula da Silva: M = 2.73, SD = 1.19, n = 11
#   Mokgweetsi Masisi: M = 3.08, SD = 1.12, n = 13
#   Lee Jae-myung: M = 2.50, SD = 1.32, n = 16
#   William Ruto: M = 2.75, SD = 1.06, n = 16
#   Yoon Suk Yeol: M = 2.94, SD = 1.48, n = 16
#   Uhuru Kenyatta: M = 2.17, SD = 1.47, n = 6
#   Jacinda Ardern: M = 2.87, SD = 1.19, n = 15
#   Anthony Albanese: M = 4.00, SD = 0.63, n = 6
#   Narendra Modi: M = 2.00, SD = 1.25, n = 10
#   Stephen Harper: M = 3.58, SD = 1.51, n = 12
#   Scott Morrison: M = 3.11, SD = 1.45, n = 18
#   Friedrich Merz: M = 2.56, SD = 1.55, n = 16
#   Rishi Sunak: M = 2.29, SD = 1.25, n = 7
#   Duma Boko: M = 3.00, SD = 0.85, n = 12
#   Prayut Chan-o-cha: M = 3.27, SD = 1.16, n = 15
#   Donald Trump: M = 2.11, SD = 1.28, n = 18
#   Christopher Luxon: M = 2.83, SD = 1.34, n = 12
#   Joe Biden: M = 2.47, SD = 1.60, n = 15
#   Justin Trudeau: M = 2.08, SD = 1.08, n = 12
#   Keir Starmer: M = 3.27, SD = 1.44, n = 15
#   Paetongtarn Shinawatra: M = 2.55, SD = 1.04, n = 11
#   Jair Bolsonaro: M = 1.85, SD = 1.14, n = 13
#   Olaf Scholz: M = 2.92, SD = 1.38, n = 12
#   Manmohan Singh: M = 2.76, SD = 1.20, n = 17
#   Statistical test result: p = 0.021
#   There are clear differences in how participants rate this trait for different politicians.
#   Effect size (epsilon squared): 0.054
# Small effect size (small practical impact).
#
# Misleading by politician:
#   Luiz Inácio Lula da Silva: M = 1.18, SD = 0.40, n = 11
#   Mokgweetsi Masisi: M = 1.62, SD = 0.77, n = 13
#   Lee Jae-myung: M = 1.75, SD = 1.13, n = 16
#   William Ruto: M = 1.94, SD = 0.93, n = 16
#   Yoon Suk Yeol: M = 1.31, SD = 0.60, n = 16
#   Uhuru Kenyatta: M = 1.00, SD = 0.63, n = 6
#   Jacinda Ardern: M = 1.73, SD = 0.88, n = 15
#   Anthony Albanese: M = 2.00, SD = 0.63, n = 6
#   Narendra Modi: M = 2.30, SD = 1.42, n = 10
#   Stephen Harper: M = 1.17, SD = 0.39, n = 12
#   Scott Morrison: M = 1.94, SD = 1.11, n = 18
#   Friedrich Merz: M = 1.81, SD = 1.28, n = 16
#   Rishi Sunak: M = 1.43, SD = 0.79, n = 7
#   Duma Boko: M = 2.08, SD = 1.16, n = 12
#   Prayut Chan-o-cha: M = 1.60, SD = 0.74, n = 15
#   Donald Trump: M = 2.11, SD = 1.28, n = 18
#   Christopher Luxon: M = 2.08, SD = 1.31, n = 12
#   Joe Biden: M = 2.38, SD = 1.50, n = 13
#   Justin Trudeau: M = 1.92, SD = 1.16, n = 12
#   Keir Starmer: M = 2.14, SD = 1.51, n = 14
#   Paetongtarn Shinawatra: M = 1.55, SD = 1.04, n = 11
#   Jair Bolsonaro: M = 3.15, SD = 1.41, n = 13
#   Olaf Scholz: M = 2.58, SD = 1.38, n = 12
#   Manmohan Singh: M = 1.47, SD = 0.87, n = 17
#   Statistical test result: p = 0.002
#   There are clear differences in how participants rate this trait for different politicians.
#   Effect size (epsilon squared): 0.082
# Medium effect size (moderate practical impact).
#
# Match_pol_comm by politician:
#   Luiz Inácio Lula da Silva: M = 2.09, SD = 0.94, n = 11
#   Mokgweetsi Masisi: M = 2.92, SD = 1.08, n = 12
#   Lee Jae-myung: M = 3.56, SD = 0.96, n = 16
#   William Ruto: M = 3.06, SD = 1.06, n = 16
#   Yoon Suk Yeol: M = 3.50, SD = 1.26, n = 16
#   Uhuru Kenyatta: M = 2.50, SD = 1.22, n = 6
#   Jacinda Ardern: M = 3.53, SD = 0.99, n = 15
#   Anthony Albanese: M = 3.00, SD = 0.89, n = 6
#   Narendra Modi: M = 3.00, SD = 1.49, n = 10
#   Stephen Harper: M = 3.92, SD = 1.08, n = 12
#   Scott Morrison: M = 3.67, SD = 0.84, n = 18
#   Friedrich Merz: M = 3.69, SD = 1.01, n = 16
#   Rishi Sunak: M = 3.43, SD = 0.98, n = 7
#   Duma Boko: M = 2.91, SD = 0.54, n = 11
#   Prayut Chan-o-cha: M = 3.27, SD = 0.88, n = 15
#   Donald Trump: M = 3.67, SD = 0.77, n = 18
#   Christopher Luxon: M = 3.09, SD = 1.04, n = 11
#   Joe Biden: M = 3.25, SD = 0.86, n = 16
#   Justin Trudeau: M = 3.33, SD = 0.89, n = 12
#   Keir Starmer: M = 2.93, SD = 0.96, n = 15
#   Paetongtarn Shinawatra: M = 3.45, SD = 0.93, n = 11
#   Jair Bolsonaro: M = 1.85, SD = 0.90, n = 13
#   Olaf Scholz: M = 3.69, SD = 1.03, n = 13
#   Manmohan Singh: M = 2.65, SD = 0.93, n = 17
#   Statistical test result: p = 0.000
#   There are clear differences in how participants rate this trait for different politicians.
#   Effect size (epsilon squared): 0.142
# Large effect size (substantial practical impact).
#
# Credible_typo_color by politician:
#   Luiz Inácio Lula da Silva: M = 2.45, SD = 1.04, n = 11
#   Mokgweetsi Masisi: M = 2.54, SD = 1.20, n = 13
#   Lee Jae-myung: M = 4.12, SD = 0.50, n = 16
#   William Ruto: M = 3.19, SD = 1.11, n = 16
#   Yoon Suk Yeol: M = 3.38, SD = 1.31, n = 16
#   Uhuru Kenyatta: M = 2.67, SD = 1.63, n = 6
#   Jacinda Ardern: M = 3.80, SD = 0.68, n = 15
#   Anthony Albanese: M = 3.17, SD = 0.98, n = 6
#   Narendra Modi: M = 2.60, SD = 1.43, n = 10
#   Stephen Harper: M = 3.17, SD = 1.03, n = 12
#   Scott Morrison: M = 3.72, SD = 0.89, n = 18
#   Friedrich Merz: M = 3.88, SD = 0.96, n = 16
#   Rishi Sunak: M = 3.29, SD = 1.25, n = 7
#   Duma Boko: M = 3.25, SD = 1.06, n = 12
#   Prayut Chan-o-cha: M = 3.33, SD = 0.90, n = 15
#   Donald Trump: M = 3.61, SD = 0.78, n = 18
#   Christopher Luxon: M = 3.67, SD = 0.65, n = 12
#   Joe Biden: M = 3.50, SD = 0.97, n = 16
#   Justin Trudeau: M = 3.67, SD = 0.78, n = 12
#   Keir Starmer: M = 2.53, SD = 0.64, n = 15
#   Paetongtarn Shinawatra: M = 3.18, SD = 0.75, n = 11
#   Jair Bolsonaro: M = 2.08, SD = 1.04, n = 13
#   Olaf Scholz: M = 3.54, SD = 0.88, n = 13
#   Manmohan Singh: M = 3.18, SD = 0.95, n = 17
#   Statistical test result: p = 0.000
#   There are clear differences in how participants rate this trait for different politicians.
#   Effect size (epsilon squared): 0.159
# Large effect size (substantial practical impact).
#
# Background by politician:
#   Luiz Inácio Lula da Silva: M = 2.55, SD = 1.13, n = 11
#   Mokgweetsi Masisi: M = 2.54, SD = 1.13, n = 13
#   Lee Jae-myung: M = 3.75, SD = 0.93, n = 16
#   William Ruto: M = 3.38, SD = 1.20, n = 16
#   Yoon Suk Yeol: M = 3.07, SD = 1.49, n = 15
#   Uhuru Kenyatta: M = 2.67, SD = 1.37, n = 6
#   Jacinda Ardern: M = 3.73, SD = 0.88, n = 15
#   Anthony Albanese: M = 2.71, SD = 1.11, n = 7
#   Narendra Modi: M = 2.80, SD = 1.40, n = 10
#   Stephen Harper: M = 2.83, SD = 1.03, n = 12
#   Scott Morrison: M = 3.22, SD = 0.94, n = 18
#   Friedrich Merz: M = 3.50, SD = 1.15, n = 16
#   Rishi Sunak: M = 3.86, SD = 0.90, n = 7
#   Duma Boko: M = 3.58, SD = 0.90, n = 12
#   Prayut Chan-o-cha: M = 3.00, SD = 1.07, n = 15
#   Donald Trump: M = 3.78, SD = 1.06, n = 18
#   Christopher Luxon: M = 3.25, SD = 1.06, n = 12
#   Joe Biden: M = 3.38, SD = 0.96, n = 16
#   Justin Trudeau: M = 3.50, SD = 0.90, n = 12
#   Keir Starmer: M = 2.40, SD = 0.74, n = 15
#   Paetongtarn Shinawatra: M = 3.18, SD = 1.08, n = 11
#   Jair Bolsonaro: M = 3.31, SD = 1.25, n = 13
#   Olaf Scholz: M = 3.38, SD = 1.19, n = 13
#   Manmohan Singh: M = 3.24, SD = 0.97, n = 17
#   Statistical test result: p = 0.013
#   There are clear differences in how participants rate this trait for different politicians.
#   Effect size (epsilon squared): 0.060
# Medium effect size (moderate practical impact).
#
# Typo_attention by politician:
#   Luiz Inácio Lula da Silva: M = 2.91, SD = 1.04, n = 11
#   Mokgweetsi Masisi: M = 3.46, SD = 1.45, n = 13
#   Lee Jae-myung: M = 3.12, SD = 1.20, n = 16
#   William Ruto: M = 3.56, SD = 1.36, n = 16
#   Yoon Suk Yeol: M = 3.27, SD = 1.33, n = 15
#   Uhuru Kenyatta: M = 2.83, SD = 1.17, n = 6
#   Jacinda Ardern: M = 3.53, SD = 0.83, n = 15
#   Anthony Albanese: M = 2.71, SD = 0.95, n = 7
#   Narendra Modi: M = 2.50, SD = 1.27, n = 10
#   Stephen Harper: M = 3.08, SD = 1.00, n = 12
#   Scott Morrison: M = 2.94, SD = 1.06, n = 18
#   Friedrich Merz: M = 3.69, SD = 1.01, n = 16
#   Rishi Sunak: M = 3.14, SD = 1.21, n = 7
#   Duma Boko: M = 3.00, SD = 0.85, n = 12
#   Prayut Chan-o-cha: M = 3.20, SD = 1.26, n = 15
#   Donald Trump: M = 2.83, SD = 1.15, n = 18
#   Christopher Luxon: M = 2.67, SD = 0.89, n = 12
#   Joe Biden: M = 3.12, SD = 1.09, n = 16
#   Justin Trudeau: M = 3.50, SD = 0.90, n = 12
#   Keir Starmer: M = 3.00, SD = 1.07, n = 15
#   Paetongtarn Shinawatra: M = 3.45, SD = 0.69, n = 11
#   Jair Bolsonaro: M = 3.38, SD = 1.12, n = 13
#   Olaf Scholz: M = 3.85, SD = 0.55, n = 13
#   Manmohan Singh: M = 2.47, SD = 0.94, n = 17
#   Statistical test result: p = 0.045
#   There are clear differences in how participants rate this trait for different politicians.
#   Effect size (epsilon squared): 0.043
# Small effect size (small practical impact).
#
# Support by politician:
#   Luiz Inácio Lula da Silva: M = 2.36, SD = 0.67, n = 11
#   Mokgweetsi Masisi: M = 2.31, SD = 1.11, n = 13
#   Lee Jae-myung: M = 2.81, SD = 1.17, n = 16
#   William Ruto: M = 2.94, SD = 1.18, n = 16
#   Yoon Suk Yeol: M = 2.62, SD = 1.20, n = 16
#   Uhuru Kenyatta: M = 2.33, SD = 1.37, n = 6
#   Jacinda Ardern: M = 3.27, SD = 0.88, n = 15
#   Anthony Albanese: M = 2.57, SD = 1.13, n = 7
#   Narendra Modi: M = 2.30, SD = 1.25, n = 10
#   Stephen Harper: M = 2.25, SD = 0.97, n = 12
#   Scott Morrison: M = 2.44, SD = 0.98, n = 18
#   Friedrich Merz: M = 3.19, SD = 1.22, n = 16
#   Rishi Sunak: M = 2.57, SD = 1.13, n = 7
#   Duma Boko: M = 2.75, SD = 0.62, n = 12
#   Prayut Chan-o-cha: M = 2.67, SD = 0.98, n = 15
#   Donald Trump: M = 2.00, SD = 0.77, n = 18
#   Christopher Luxon: M = 2.58, SD = 1.24, n = 12
#   Joe Biden: M = 2.53, SD = 1.19, n = 15
#   Justin Trudeau: M = 2.67, SD = 0.89, n = 12
#   Keir Starmer: M = 2.40, SD = 0.91, n = 15
#   Paetongtarn Shinawatra: M = 2.91, SD = 0.70, n = 11
#   Jair Bolsonaro: M = 1.85, SD = 1.21, n = 13
#   Olaf Scholz: M = 2.77, SD = 1.01, n = 13
#   Manmohan Singh: M = 3.18, SD = 0.95, n = 17
#   Statistical test result: p = 0.025
#   There are clear differences in how participants rate this trait for different politicians.
#   Effect size (epsilon squared): 0.052
# Small effect size (small practical impact).
#
# Interested_in by politician:
#   Luiz Inácio Lula da Silva: M = 2.36, SD = 1.03, n = 11
#   Mokgweetsi Masisi: M = 2.69, SD = 1.44, n = 13
#   Lee Jae-myung: M = 3.31, SD = 0.87, n = 16
#   William Ruto: M = 3.12, SD = 1.36, n = 16
#   Yoon Suk Yeol: M = 2.69, SD = 1.25, n = 16
#   Uhuru Kenyatta: M = 2.67, SD = 1.03, n = 6
#   Jacinda Ardern: M = 3.20, SD = 0.94, n = 15
#   Anthony Albanese: M = 2.29, SD = 1.11, n = 7
#   Narendra Modi: M = 2.70, SD = 1.34, n = 10
#   Stephen Harper: M = 2.00, SD = 0.95, n = 12
#   Scott Morrison: M = 2.50, SD = 0.86, n = 18
#   Friedrich Merz: M = 3.12, SD = 1.15, n = 16
#   Rishi Sunak: M = 3.14, SD = 1.21, n = 7
#   Duma Boko: M = 2.75, SD = 1.06, n = 12
#   Prayut Chan-o-cha: M = 2.53, SD = 1.19, n = 15
#   Donald Trump: M = 2.28, SD = 1.07, n = 18
#   Christopher Luxon: M = 2.92, SD = 1.16, n = 12
#   Joe Biden: M = 2.56, SD = 1.09, n = 16
#   Justin Trudeau: M = 3.00, SD = 0.95, n = 12
#   Keir Starmer: M = 2.33, SD = 0.72, n = 15
#   Paetongtarn Shinawatra: M = 3.09, SD = 0.94, n = 11
#   Jair Bolsonaro: M = 2.85, SD = 1.63, n = 13
#   Olaf Scholz: M = 3.23, SD = 1.17, n = 13
#   Manmohan Singh: M = 2.71, SD = 1.16, n = 17
#   Statistical test result: p = 0.147
#   No meaningful differences in ratings between politicians for this trait.
#
# === GEOGRAPHICAL EFFECT ON PERCEPTION (BASELINE) ===
# Comparing continents: ['Europe', 'Asia', 'Americas', 'Oceania', 'Africa']
#
# Competence overall perception analysis - Participant vs Politician Origin:
#   Same continent (participant-politician): M = 2.98, SD = 1.18, n = 61, Range = 1.0-5.0
#   Different continent (participant-politician): M = 3.21, SD = 1.13, n = 253, Range = 1.0-5.0
#   Mann-Whitney U test: U = 6915.0, p = 0.192
#   **Fail to reject H₀**: No significant overall cross-cultural bias detected for competence perception
#
# Detailed continent by continent analysis:
#
#     Participants from Americas:
#       → Rate Americas politicians: M = 2.00, n = 15 (SAME CONTINENT)
#       → Rate Europe politicians: M = 4.14, n = 7 (DIFFERENT CONTINENT)
#       → Rate Asia politicians: M = 3.53, n = 15 (DIFFERENT CONTINENT)
#       → Rate Oceania politicians: M = 3.50, n = 6 (DIFFERENT CONTINENT)
#       → Rate Africa politicians: M = 3.60, n = 5 (DIFFERENT CONTINENT)
#       → **Americas participants gave lower competence ratings to politicians from their continent (p = 0.000, r_rb = 0.683)**
#
#     Participants from Europe:
#       → Rate Americas politicians: M = 2.59, n = 22 (DIFFERENT CONTINENT)
#       → Rate Europe politicians: M = 3.25, n = 16 (SAME CONTINENT)
#       → Rate Asia politicians: M = 3.06, n = 34 (DIFFERENT CONTINENT)
#       → Rate Oceania politicians: M = 2.90, n = 20 (DIFFERENT CONTINENT)
#       → Rate Africa politicians: M = 3.56, n = 16 (DIFFERENT CONTINENT)
#
#     Participants from Asia:
#       → Rate Americas politicians: M = 3.07, n = 27 (DIFFERENT CONTINENT)
#       → Rate Europe politicians: M = 3.58, n = 19 (DIFFERENT CONTINENT)
#       → Rate Asia politicians: M = 3.13, n = 23 (SAME CONTINENT)
#       → Rate Oceania politicians: M = 3.31, n = 16 (DIFFERENT CONTINENT)
#       → Rate Africa politicians: M = 3.61, n = 18 (DIFFERENT CONTINENT)
#
#     Participants from Oceania:
#       → Rate Americas politicians: M = 2.33, n = 12 (DIFFERENT CONTINENT)
#       → Rate Europe politicians: M = 3.00, n = 8 (DIFFERENT CONTINENT)
#       → Rate Asia politicians: M = 3.55, n = 11 (DIFFERENT CONTINENT)
#       → Rate Oceania politicians: M = 4.20, n = 5 (SAME CONTINENT)
#       → Rate Africa politicians: M = 3.00, n = 6 (DIFFERENT CONTINENT)
#       → **Oceania participants gave higher competence ratings to politicians from their continent (p = 0.019, r_rb = -0.632)**
#
#     Participants from Africa:
#       → Rate Americas politicians: M = 2.60, n = 5 (DIFFERENT CONTINENT)
#
# Likable overall perception analysis - Participant vs Politician Origin:
#   Same continent (participant-politician): M = 2.97, SD = 1.28, n = 61, Range = 1.0-5.0
#   Different continent (participant-politician): M = 3.11, SD = 1.19, n = 253, Range = 1.0-5.0
#   Mann-Whitney U test: U = 7217.0, p = 0.419
#   **Fail to reject H₀**: No significant overall cross-cultural bias detected for likable perception
#
# Detailed continent by continent analysis:
#
#     Participants from Americas:
#       → Rate Americas politicians: M = 2.27, n = 15 (SAME CONTINENT)
#       → Rate Europe politicians: M = 3.29, n = 7 (DIFFERENT CONTINENT)
#       → Rate Asia politicians: M = 3.40, n = 15 (DIFFERENT CONTINENT)
#       → Rate Oceania politicians: M = 3.33, n = 6 (DIFFERENT CONTINENT)
#       → Rate Africa politicians: M = 4.40, n = 5 (DIFFERENT CONTINENT)
#       → **Americas participants gave lower likable ratings to politicians from their continent (p = 0.007, r_rb = 0.483)**
#
#     Participants from Europe:
#       → Rate Americas politicians: M = 2.36, n = 22 (DIFFERENT CONTINENT)
#       → Rate Europe politicians: M = 2.62, n = 16 (SAME CONTINENT)
#       → Rate Asia politicians: M = 3.26, n = 34 (DIFFERENT CONTINENT)
#       → Rate Oceania politicians: M = 2.65, n = 20 (DIFFERENT CONTINENT)
#       → Rate Africa politicians: M = 3.44, n = 16 (DIFFERENT CONTINENT)
#
#     Participants from Asia:
#       → Rate Americas politicians: M = 2.96, n = 27 (DIFFERENT CONTINENT)
#       → Rate Europe politicians: M = 3.16, n = 19 (DIFFERENT CONTINENT)
#       → Rate Asia politicians: M = 3.30, n = 23 (SAME CONTINENT)
#       → Rate Oceania politicians: M = 3.00, n = 16 (DIFFERENT CONTINENT)
#       → Rate Africa politicians: M = 3.78, n = 18 (DIFFERENT CONTINENT)
#
#     Participants from Oceania:
#       → Rate Americas politicians: M = 2.33, n = 12 (DIFFERENT CONTINENT)
#       → Rate Europe politicians: M = 2.12, n = 8 (DIFFERENT CONTINENT)
#       → Rate Asia politicians: M = 3.55, n = 11 (DIFFERENT CONTINENT)
#       → Rate Oceania politicians: M = 4.20, n = 5 (SAME CONTINENT)
#       → Rate Africa politicians: M = 3.50, n = 6 (DIFFERENT CONTINENT)
#       → **Oceania participants gave higher likable ratings to politicians from their continent (p = 0.018, r_rb = -0.638)**
#
#     Participants from Africa:
#       → Rate Americas politicians: M = 3.40, n = 5 (DIFFERENT CONTINENT)
#
# Trustworthy overall perception analysis - Participant vs Politician Origin:
#   Same continent (participant-politician): M = 2.80, SD = 1.15, n = 61, Range = 1.0-5.0
#   Different continent (participant-politician): M = 2.93, SD = 1.17, n = 254, Range = 1.0-5.0
#   Mann-Whitney U test: U = 7356.0, p = 0.528
#   **Fail to reject H₀**: No significant overall cross-cultural bias detected for trustworthy perception
#
# Detailed continent by continent analysis:
#
#     Participants from Americas:
#       → Rate Americas politicians: M = 2.07, n = 15 (SAME CONTINENT)
#       → Rate Europe politicians: M = 3.86, n = 7 (DIFFERENT CONTINENT)
#       → Rate Asia politicians: M = 3.27, n = 15 (DIFFERENT CONTINENT)
#       → Rate Oceania politicians: M = 3.00, n = 6 (DIFFERENT CONTINENT)
#       → Rate Africa politicians: M = 3.60, n = 5 (DIFFERENT CONTINENT)
#       → **Americas participants gave lower trustworthy ratings to politicians from their continent (p = 0.002, r_rb = 0.547)**
#
#     Participants from Europe:
#       → Rate Americas politicians: M = 2.45, n = 22 (DIFFERENT CONTINENT)
#       → Rate Europe politicians: M = 2.81, n = 16 (SAME CONTINENT)
#       → Rate Asia politicians: M = 3.15, n = 34 (DIFFERENT CONTINENT)
#       → Rate Oceania politicians: M = 2.50, n = 20 (DIFFERENT CONTINENT)
#       → Rate Africa politicians: M = 2.94, n = 16 (DIFFERENT CONTINENT)
#
#     Participants from Asia:
#       → Rate Americas politicians: M = 2.67, n = 27 (DIFFERENT CONTINENT)
#       → Rate Europe politicians: M = 3.16, n = 19 (DIFFERENT CONTINENT)
#       → Rate Asia politicians: M = 3.00, n = 23 (SAME CONTINENT)
#       → Rate Oceania politicians: M = 3.24, n = 17 (DIFFERENT CONTINENT)
#       → Rate Africa politicians: M = 3.28, n = 18 (DIFFERENT CONTINENT)
#
#     Participants from Oceania:
#       → Rate Americas politicians: M = 1.92, n = 12 (DIFFERENT CONTINENT)
#       → Rate Europe politicians: M = 2.00, n = 8 (DIFFERENT CONTINENT)
#       → Rate Asia politicians: M = 3.18, n = 11 (DIFFERENT CONTINENT)
#       → Rate Oceania politicians: M = 4.00, n = 5 (SAME CONTINENT)
#       → Rate Africa politicians: M = 3.00, n = 6 (DIFFERENT CONTINENT)
#       → **Oceania participants gave higher trustworthy ratings to politicians from their continent (p = 0.015, r_rb = -0.659)**
#
#     Participants from Africa:
#       → Rate Americas politicians: M = 3.40, n = 5 (DIFFERENT CONTINENT)
#
# Approachable overall perception analysis - Participant vs Politician Origin:
#   Same continent (participant-politician): M = 2.90, SD = 1.29, n = 61, Range = 1.0-5.0
#   Different continent (participant-politician): M = 3.08, SD = 1.27, n = 254, Range = 1.0-5.0
#   Mann-Whitney U test: U = 7114.0, p = 0.311
#   **Fail to reject H₀**: No significant overall cross-cultural bias detected for approachable perception
#
# Detailed continent by continent analysis:
#
#     Participants from Americas:
#       → Rate Americas politicians: M = 2.33, n = 15 (SAME CONTINENT)
#       → Rate Europe politicians: M = 3.29, n = 7 (DIFFERENT CONTINENT)
#       → Rate Asia politicians: M = 3.67, n = 15 (DIFFERENT CONTINENT)
#       → Rate Oceania politicians: M = 3.50, n = 6 (DIFFERENT CONTINENT)
#       → Rate Africa politicians: M = 4.20, n = 5 (DIFFERENT CONTINENT)
#       → **Americas participants gave lower approachable ratings to politicians from their continent (p = 0.005, r_rb = 0.495)**
#
#     Participants from Europe:
#       → Rate Americas politicians: M = 2.77, n = 22 (DIFFERENT CONTINENT)
#       → Rate Europe politicians: M = 2.50, n = 16 (SAME CONTINENT)
#       → Rate Asia politicians: M = 3.29, n = 34 (DIFFERENT CONTINENT)
#       → Rate Oceania politicians: M = 2.85, n = 20 (DIFFERENT CONTINENT)
#       → Rate Africa politicians: M = 3.12, n = 16 (DIFFERENT CONTINENT)
#
#     Participants from Asia:
#       → Rate Americas politicians: M = 2.59, n = 27 (DIFFERENT CONTINENT)
#       → Rate Europe politicians: M = 2.84, n = 19 (DIFFERENT CONTINENT)
#       → Rate Asia politicians: M = 3.22, n = 23 (SAME CONTINENT)
#       → Rate Oceania politicians: M = 3.29, n = 17 (DIFFERENT CONTINENT)
#       → Rate Africa politicians: M = 3.44, n = 18 (DIFFERENT CONTINENT)
#
#     Participants from Oceania:
#       → Rate Americas politicians: M = 2.58, n = 12 (DIFFERENT CONTINENT)
#       → Rate Europe politicians: M = 1.88, n = 8 (DIFFERENT CONTINENT)
#       → Rate Asia politicians: M = 3.64, n = 11 (DIFFERENT CONTINENT)
#       → Rate Oceania politicians: M = 4.20, n = 5 (SAME CONTINENT)
#       → Rate Africa politicians: M = 3.83, n = 6 (DIFFERENT CONTINENT)
#       → **Oceania participants gave higher approachable ratings to politicians from their continent (p = 0.046, r_rb = -0.546)**
#
#     Participants from Africa:
#       → Rate Americas politicians: M = 2.80, n = 5 (DIFFERENT CONTINENT)
#
# Charismatic overall perception analysis - Participant vs Politician Origin:
#   Same continent (participant-politician): M = 3.00, SD = 1.22, n = 61, Range = 1.0-5.0
#   Different continent (participant-politician): M = 2.99, SD = 1.16, n = 252, Range = 1.0-5.0
#   Mann-Whitney U test: U = 7699.0, p = 0.984
#   **Fail to reject H₀**: No significant overall cross-cultural bias detected for charismatic perception
#
# Detailed continent by continent analysis:
#
#     Participants from Americas:
#       → Rate Americas politicians: M = 2.60, n = 15 (SAME CONTINENT)
#       → Rate Europe politicians: M = 2.86, n = 7 (DIFFERENT CONTINENT)
#       → Rate Asia politicians: M = 3.07, n = 15 (DIFFERENT CONTINENT)
#       → Rate Oceania politicians: M = 3.17, n = 6 (DIFFERENT CONTINENT)
#       → Rate Africa politicians: M = 4.20, n = 5 (DIFFERENT CONTINENT)
#
#     Participants from Europe:
#       → Rate Americas politicians: M = 2.64, n = 22 (DIFFERENT CONTINENT)
#       → Rate Europe politicians: M = 2.62, n = 16 (SAME CONTINENT)
#       → Rate Asia politicians: M = 3.09, n = 34 (DIFFERENT CONTINENT)
#       → Rate Oceania politicians: M = 2.70, n = 20 (DIFFERENT CONTINENT)
#       → Rate Africa politicians: M = 3.06, n = 16 (DIFFERENT CONTINENT)
#
#     Participants from Asia:
#       → Rate Americas politicians: M = 2.70, n = 27 (DIFFERENT CONTINENT)
#       → Rate Europe politicians: M = 3.32, n = 19 (DIFFERENT CONTINENT)
#       → Rate Asia politicians: M = 3.26, n = 23 (SAME CONTINENT)
#       → Rate Oceania politicians: M = 3.06, n = 17 (DIFFERENT CONTINENT)
#       → Rate Africa politicians: M = 3.11, n = 18 (DIFFERENT CONTINENT)
#
#     Participants from Oceania:
#       → Rate Americas politicians: M = 2.92, n = 12 (DIFFERENT CONTINENT)
#       → Rate Europe politicians: M = 1.86, n = 7 (DIFFERENT CONTINENT)
#       → Rate Asia politicians: M = 3.55, n = 11 (DIFFERENT CONTINENT)
#       → Rate Oceania politicians: M = 4.00, n = 5 (SAME CONTINENT)
#       → Rate Africa politicians: M = 3.20, n = 5 (DIFFERENT CONTINENT)
#
#     Participants from Africa:
#       → Rate Americas politicians: M = 3.20, n = 5 (DIFFERENT CONTINENT)
#
# Aggressive overall perception analysis - Participant vs Politician Origin:
#   Same continent (participant-politician): M = 2.46, SD = 1.30, n = 61, Range = 1.0-5.0
#   Different continent (participant-politician): M = 2.19, SD = 1.25, n = 252, Range = 0.0-5.0
#   Mann-Whitney U test: U = 8599.0, p = 0.134
#   **Fail to reject H₀**: No significant overall cross-cultural bias detected for aggressive perception
#
# Detailed continent by continent analysis:
#
#     Participants from Americas:
#       → Rate Americas politicians: M = 2.80, n = 15 (SAME CONTINENT)
#       → Rate Europe politicians: M = 2.57, n = 7 (DIFFERENT CONTINENT)
#       → Rate Asia politicians: M = 1.80, n = 15 (DIFFERENT CONTINENT)
#       → Rate Oceania politicians: M = 2.17, n = 6 (DIFFERENT CONTINENT)
#       → Rate Africa politicians: M = 1.80, n = 5 (DIFFERENT CONTINENT)
#
#     Participants from Europe:
#       → Rate Americas politicians: M = 1.90, n = 21 (DIFFERENT CONTINENT)
#       → Rate Europe politicians: M = 2.56, n = 16 (SAME CONTINENT)
#       → Rate Asia politicians: M = 1.71, n = 34 (DIFFERENT CONTINENT)
#       → Rate Oceania politicians: M = 2.40, n = 20 (DIFFERENT CONTINENT)
#       → Rate Africa politicians: M = 2.38, n = 16 (DIFFERENT CONTINENT)
#
#     Participants from Asia:
#       → Rate Americas politicians: M = 2.70, n = 27 (DIFFERENT CONTINENT)
#       → Rate Europe politicians: M = 2.63, n = 19 (DIFFERENT CONTINENT)
#       → Rate Asia politicians: M = 2.30, n = 23 (SAME CONTINENT)
#       → Rate Oceania politicians: M = 2.53, n = 17 (DIFFERENT CONTINENT)
#       → Rate Africa politicians: M = 1.89, n = 18 (DIFFERENT CONTINENT)
#
#     Participants from Oceania:
#       → Rate Americas politicians: M = 2.27, n = 11 (DIFFERENT CONTINENT)
#       → Rate Europe politicians: M = 2.38, n = 8 (DIFFERENT CONTINENT)
#       → Rate Asia politicians: M = 1.27, n = 11 (DIFFERENT CONTINENT)
#       → Rate Oceania politicians: M = 2.00, n = 5 (SAME CONTINENT)
#       → Rate Africa politicians: M = 1.67, n = 6 (DIFFERENT CONTINENT)
#
#     Participants from Africa:
#       → Rate Americas politicians: M = 2.80, n = 5 (DIFFERENT CONTINENT)
#
# Friendly overall perception analysis - Participant vs Politician Origin:
#   Same continent (participant-politician): M = 2.97, SD = 1.24, n = 61, Range = 1.0-5.0
#   Different continent (participant-politician): M = 3.08, SD = 1.24, n = 253, Range = 1.0-5.0
#   Mann-Whitney U test: U = 7328.5, p = 0.532
#   **Fail to reject H₀**: No significant overall cross-cultural bias detected for friendly perception
#
# Detailed continent by continent analysis:
#
#     Participants from Americas:
#       → Rate Americas politicians: M = 2.33, n = 15 (SAME CONTINENT)
#       → Rate Europe politicians: M = 3.43, n = 7 (DIFFERENT CONTINENT)
#       → Rate Asia politicians: M = 3.60, n = 15 (DIFFERENT CONTINENT)
#       → Rate Oceania politicians: M = 3.67, n = 6 (DIFFERENT CONTINENT)
#       → Rate Africa politicians: M = 4.00, n = 5 (DIFFERENT CONTINENT)
#       → **Americas participants gave lower friendly ratings to politicians from their continent (p = 0.002, r_rb = 0.547)**
#
#     Participants from Europe:
#       → Rate Americas politicians: M = 2.50, n = 22 (DIFFERENT CONTINENT)
#       → Rate Europe politicians: M = 2.69, n = 16 (SAME CONTINENT)
#       → Rate Asia politicians: M = 3.50, n = 34 (DIFFERENT CONTINENT)
#       → Rate Oceania politicians: M = 2.65, n = 20 (DIFFERENT CONTINENT)
#       → Rate Africa politicians: M = 3.19, n = 16 (DIFFERENT CONTINENT)
#
#     Participants from Asia:
#       → Rate Americas politicians: M = 2.96, n = 27 (DIFFERENT CONTINENT)
#       → Rate Europe politicians: M = 2.84, n = 19 (DIFFERENT CONTINENT)
#       → Rate Asia politicians: M = 3.30, n = 23 (SAME CONTINENT)
#       → Rate Oceania politicians: M = 3.18, n = 17 (DIFFERENT CONTINENT)
#       → Rate Africa politicians: M = 3.50, n = 18 (DIFFERENT CONTINENT)
#
#     Participants from Oceania:
#       → Rate Americas politicians: M = 2.33, n = 12 (DIFFERENT CONTINENT)
#       → Rate Europe politicians: M = 2.00, n = 7 (DIFFERENT CONTINENT)
#       → Rate Asia politicians: M = 3.55, n = 11 (DIFFERENT CONTINENT)
#       → Rate Oceania politicians: M = 4.00, n = 5 (SAME CONTINENT)
#       → Rate Africa politicians: M = 3.17, n = 6 (DIFFERENT CONTINENT)
#       → **Oceania participants gave higher friendly ratings to politicians from their continent (p = 0.021, r_rb = -0.617)**
#
#     Participants from Africa:
#       → Rate Americas politicians: M = 2.40, n = 5 (DIFFERENT CONTINENT)
#
# Professional overall perception analysis - Participant vs Politician Origin:
#   Same continent (participant-politician): M = 3.28, SD = 1.21, n = 61, Range = 1.0-5.0
#   Different continent (participant-politician): M = 3.43, SD = 1.17, n = 254, Range = 1.0-5.0
#   Mann-Whitney U test: U = 7255.5, p = 0.426
#   **Fail to reject H₀**: No significant overall cross-cultural bias detected for professional perception
#
# Detailed continent by continent analysis:
#
#     Participants from Americas:
#       → Rate Americas politicians: M = 2.53, n = 15 (SAME CONTINENT)
#       → Rate Europe politicians: M = 4.14, n = 7 (DIFFERENT CONTINENT)
#       → Rate Asia politicians: M = 3.73, n = 15 (DIFFERENT CONTINENT)
#       → Rate Oceania politicians: M = 3.83, n = 6 (DIFFERENT CONTINENT)
# ...
#   Slightly familiar: Average rating = 2.07 (n = 29)
#   Very familiar: Average rating = 2.38 (n = 21)
#   Extremely familiar: Average rating = 3.18 (n = 22)
#   Statistical test: p = 0.025
#   Familiarity DOES affect ratings for aggressive.
#   Effect size (epsilon squared): 0.023
# Small effect size (small practical impact).
#     People who are 'Extremely familiar' gave the HIGHEST ratings (3.18).
#     People who are 'Slightly familiar' gave the LOWEST ratings (2.07).
#
# Friendly by familiarity:
#   Not familiar at all: Average rating = 3.13 (n = 200)
#   Moderately familiar: Average rating = 3.35 (n = 40)
#   Slightly familiar: Average rating = 3.10 (n = 30)
#   Very familiar: Average rating = 3.09 (n = 22)
#   Extremely familiar: Average rating = 1.82 (n = 22)
#   Statistical test: p = 0.000
#   Familiarity DOES affect ratings for friendly.
#   Effect size (epsilon squared): 0.057
# Small effect size (small practical impact).
#     People who are 'Moderately familiar' gave the HIGHEST ratings (3.35).
#     People who are 'Extremely familiar' gave the LOWEST ratings (1.82).
#
# Professional by familiarity:
#   Not familiar at all: Average rating = 3.39 (n = 200)
#   Moderately familiar: Average rating = 3.51 (n = 41)
#   Slightly familiar: Average rating = 3.60 (n = 30)
#   Very familiar: Average rating = 3.55 (n = 22)
#   Extremely familiar: Average rating = 2.82 (n = 22)
#   Statistical test: p = 0.310
#
# Visually_appealing by familiarity:
#   Not familiar at all: Average rating = 2.99 (n = 199)
#   Moderately familiar: Average rating = 3.39 (n = 41)
#   Slightly familiar: Average rating = 3.23 (n = 30)
#   Very familiar: Average rating = 3.09 (n = 22)
#   Extremely familiar: Average rating = 3.18 (n = 22)
#   Statistical test: p = 0.394
#
# Professionally_designed by familiarity:
#   Not familiar at all: Average rating = 3.05 (n = 199)
#   Moderately familiar: Average rating = 3.44 (n = 41)
#   Slightly familiar: Average rating = 3.23 (n = 30)
#   Very familiar: Average rating = 3.68 (n = 22)
#   Extremely familiar: Average rating = 3.05 (n = 22)
#   Statistical test: p = 0.145
#
# Aggressive_poster by familiarity:
#   Not familiar at all: Average rating = 1.89 (n = 199)
#   Moderately familiar: Average rating = 2.54 (n = 41)
#   Slightly familiar: Average rating = 2.17 (n = 30)
#   Very familiar: Average rating = 1.90 (n = 21)
#   Extremely familiar: Average rating = 2.36 (n = 22)
#   Statistical test: p = 0.066
#
# Inspirational by familiarity:
#   Not familiar at all: Average rating = 2.17 (n = 199)
#   Moderately familiar: Average rating = 2.78 (n = 41)
#   Slightly familiar: Average rating = 2.17 (n = 30)
#   Very familiar: Average rating = 2.73 (n = 22)
#   Extremely familiar: Average rating = 2.09 (n = 22)
#   Statistical test: p = 0.024
#   Familiarity DOES affect ratings for inspirational.
#   Effect size (epsilon squared): 0.024
# Small effect size (small practical impact).
#     People who are 'Moderately familiar' gave the HIGHEST ratings (2.78).
#     People who are 'Extremely familiar' gave the LOWEST ratings (2.09).
#
# Manipulative by familiarity:
#   Not familiar at all: Average rating = 1.83 (n = 199)
#   Moderately familiar: Average rating = 2.65 (n = 40)
#   Slightly familiar: Average rating = 2.23 (n = 30)
#   Very familiar: Average rating = 2.10 (n = 21)
#   Extremely familiar: Average rating = 2.59 (n = 22)
#   Statistical test: p = 0.000
#   Familiarity DOES affect ratings for manipulative.
#   Effect size (epsilon squared): 0.052
# Small effect size (small practical impact).
#     People who are 'Moderately familiar' gave the HIGHEST ratings (2.65).
#     People who are 'Not familiar at all' gave the LOWEST ratings (1.83).
#
# Boring by familiarity:
#   Not familiar at all: Average rating = 2.79 (n = 199)
#   Moderately familiar: Average rating = 2.63 (n = 41)
#   Slightly familiar: Average rating = 2.93 (n = 30)
#   Very familiar: Average rating = 2.59 (n = 22)
#   Extremely familiar: Average rating = 2.32 (n = 22)
#   Statistical test: p = 0.467
#
# Misleading by familiarity:
#   Not familiar at all: Average rating = 1.69 (n = 199)
#   Moderately familiar: Average rating = 2.33 (n = 40)
#   Slightly familiar: Average rating = 2.07 (n = 30)
#   Very familiar: Average rating = 1.71 (n = 21)
#   Extremely familiar: Average rating = 2.48 (n = 21)
#   Statistical test: p = 0.014
#   Familiarity DOES affect ratings for misleading.
#   Effect size (epsilon squared): 0.028
# Small effect size (small practical impact).
#     People who are 'Extremely familiar' gave the HIGHEST ratings (2.48).
#     People who are 'Not familiar at all' gave the LOWEST ratings (1.69).
#
# Match_pol_comm by familiarity:
#   Not familiar at all: Average rating = 3.08 (n = 197)
#   Moderately familiar: Average rating = 3.56 (n = 41)
#   Slightly familiar: Average rating = 3.35 (n = 31)
#   Very familiar: Average rating = 3.23 (n = 22)
#   Extremely familiar: Average rating = 3.45 (n = 22)
#   Statistical test: p = 0.086
#
# Credible_typo_color by familiarity:
#   Not familiar at all: Average rating = 3.19 (n = 200)
#   Moderately familiar: Average rating = 3.39 (n = 41)
#   Slightly familiar: Average rating = 3.45 (n = 31)
#   Very familiar: Average rating = 3.41 (n = 22)
#   Extremely familiar: Average rating = 3.50 (n = 22)
#   Statistical test: p = 0.577
#
# Background by familiarity:
#   Not familiar at all: Average rating = 3.14 (n = 201)
#   Moderately familiar: Average rating = 3.24 (n = 41)
#   Slightly familiar: Average rating = 3.30 (n = 30)
#   Very familiar: Average rating = 3.59 (n = 22)
#   Extremely familiar: Average rating = 3.45 (n = 22)
#   Statistical test: p = 0.365
#
# Typo_attention by familiarity:
#   Not familiar at all: Average rating = 3.13 (n = 200)
#   Moderately familiar: Average rating = 3.22 (n = 41)
#   Slightly familiar: Average rating = 2.94 (n = 31)
#   Very familiar: Average rating = 3.32 (n = 22)
#   Extremely familiar: Average rating = 3.32 (n = 22)
#   Statistical test: p = 0.611
#
# Support by familiarity:
#   Not familiar at all: Average rating = 2.60 (n = 201)
#   Moderately familiar: Average rating = 2.88 (n = 41)
#   Slightly familiar: Average rating = 2.57 (n = 30)
#   Very familiar: Average rating = 2.86 (n = 22)
#   Extremely familiar: Average rating = 2.09 (n = 22)
#   Statistical test: p = 0.073
#
# Interested_in by familiarity:
#   Not familiar at all: Average rating = 2.80 (n = 201)
#   Moderately familiar: Average rating = 3.00 (n = 41)
#   Slightly familiar: Average rating = 2.71 (n = 31)
#   Very familiar: Average rating = 2.82 (n = 22)
#   Extremely familiar: Average rating = 1.91 (n = 22)
#   Statistical test: p = 0.006
#   Familiarity DOES affect ratings for interested_in.
#   Effect size (epsilon squared): 0.033
# Small effect size (small practical impact).
#     People who are 'Moderately familiar' gave the HIGHEST ratings (3.00).
#     People who are 'Extremely familiar' gave the LOWEST ratings (1.91).
#
# === OPINION SHIFT AFTER VIEWING POSTERS ===
# Wilcoxon Signed-Rank test for opinion shift (pre vs post):
#   n = 313
#   Statistic = 5388.00, p-value = 0.0015
#   Skewness pre-opinion = -0.99, Skewness post-opinion = -0.51
#   Median pre-opinion = 3.00, Median post-opinion = 3.00
#   **Significant shift in opinion after viewing the poster**
#   Participants viewed the politicians more positively after viewing (r_rb = 0.259)
#
# === UNDERSTANDING EFFECTS ON PERCEPTION ===
#
# Participant Group Distribution:
#   Understood BOTH language and poster meaning: 194 participants
#   Understood ONLY language: 16 participants
#   Understood ONLY poster meaning: 46 participants
#   Did NOT understand language NOR poster meaning: 62 participants
#
# --- Trait: Competence ---
#   Understood BOTH language and poster meaning: Mean=3.07, SD=1.17, n=192
#   Understood ONLY language: Mean=3.50, SD=1.21, n=16
#   Understood ONLY poster meaning: Mean=3.39, SD=1.08, n=46
#   Did NOT understand language NOR poster meaning: Mean=3.22, SD=1.08, n=60
#   Kruskal-Wallis test: H=3.85, p=0.279
#  No significant differences between understanding groups.
#
# --- Trait: Likable ---
#   Understood BOTH language and poster meaning: Mean=3.03, SD=1.26, n=192
#   Understood ONLY language: Mean=3.69, SD=1.25, n=16
#   Understood ONLY poster meaning: Mean=3.17, SD=1.08, n=46
#   Did NOT understand language NOR poster meaning: Mean=3.02, SD=1.11, n=60
#   Kruskal-Wallis test: H=4.84, p=0.184
#  No significant differences between understanding groups.
#
# --- Trait: Trustworthy ---
#   Understood BOTH language and poster meaning: Mean=2.88, SD=1.18, n=193
#   Understood ONLY language: Mean=3.12, SD=1.31, n=16
#   Understood ONLY poster meaning: Mean=2.96, SD=1.13, n=46
#   Did NOT understand language NOR poster meaning: Mean=2.90, SD=1.13, n=60
#   Kruskal-Wallis test: H=0.59, p=0.900
#  No significant differences between understanding groups.
#
# --- Trait: Approachable ---
#   Understood BOTH language and poster meaning: Mean=2.97, SD=1.26, n=193
#   Understood ONLY language: Mean=3.44, SD=1.46, n=16
#   Understood ONLY poster meaning: Mean=3.07, SD=1.34, n=46
#   Did NOT understand language NOR poster meaning: Mean=3.17, SD=1.21, n=60
#   Kruskal-Wallis test: H=2.72, p=0.438
#  No significant differences between understanding groups.
#
# --- Trait: Charismatic ---
#   Understood BOTH language and poster meaning: Mean=2.94, SD=1.19, n=191
#   Understood ONLY language: Mean=3.44, SD=1.26, n=16
#   Understood ONLY poster meaning: Mean=3.11, SD=1.10, n=46
#   Did NOT understand language NOR poster meaning: Mean=2.95, SD=1.13, n=60
#   Kruskal-Wallis test: H=3.60, p=0.308
#  No significant differences between understanding groups.
#
# --- Trait: Aggressive ---
#   Understood BOTH language and poster meaning: Mean=2.36, SD=1.33, n=191
#   Understood ONLY language: Mean=2.50, SD=1.37, n=16
#   Understood ONLY poster meaning: Mean=2.11, SD=1.16, n=46
#   Did NOT understand language NOR poster meaning: Mean=1.92, SD=1.03, n=60
#   Kruskal-Wallis test: H=5.55, p=0.136
#  No significant differences between understanding groups.
#
# --- Trait: Friendly ---
#   Understood BOTH language and poster meaning: Mean=2.93, SD=1.30, n=192
#   Understood ONLY language: Mean=3.38, SD=1.36, n=16
#   Understood ONLY poster meaning: Mean=3.35, SD=1.02, n=46
#   Did NOT understand language NOR poster meaning: Mean=3.17, SD=1.12, n=60
#   Kruskal-Wallis test: H=5.79, p=0.122
#  No significant differences between understanding groups.
#
# --- Trait: Professional ---
#   Understood BOTH language and poster meaning: Mean=3.34, SD=1.15, n=193
#   Understood ONLY language: Mean=3.50, SD=1.32, n=16
#   Understood ONLY poster meaning: Mean=3.35, SD=1.27, n=46
#   Did NOT understand language NOR poster meaning: Mean=3.60, SD=1.17, n=60
#   Kruskal-Wallis test: H=3.23, p=0.358
#  No significant differences between understanding groups.
#
# --- Trait: Visually_appealing ---
#   Understood BOTH language and poster meaning: Mean=3.03, SD=1.25, n=193
#   Understood ONLY language: Mean=3.38, SD=1.15, n=16
#   Understood ONLY poster meaning: Mean=3.38, SD=1.23, n=45
#   Did NOT understand language NOR poster meaning: Mean=2.98, SD=1.32, n=60
#   Kruskal-Wallis test: H=4.08, p=0.253
#  No significant differences between understanding groups.
#
# --- Trait: Professionally_designed ---
#   Understood BOTH language and poster meaning: Mean=3.11, SD=1.29, n=193
#   Understood ONLY language: Mean=3.00, SD=1.21, n=16
#   Understood ONLY poster meaning: Mean=3.49, SD=1.32, n=45
#   Did NOT understand language NOR poster meaning: Mean=3.12, SD=1.22, n=60
#   Kruskal-Wallis test: H=3.70, p=0.296
#  No significant differences between understanding groups.
#
# --- Trait: Aggressive_poster ---
#   Understood BOTH language and poster meaning: Mean=2.10, SD=1.29, n=192
#   Understood ONLY language: Mean=2.19, SD=1.28, n=16
#   Understood ONLY poster meaning: Mean=2.07, SD=1.29, n=45
#   Did NOT understand language NOR poster meaning: Mean=1.75, SD=1.19, n=60
#   Kruskal-Wallis test: H=4.93, p=0.177
#  No significant differences between understanding groups.
#
# --- Trait: Inspirational ---
#   Understood BOTH language and poster meaning: Mean=2.28, SD=1.23, n=193
#   Understood ONLY language: Mean=2.56, SD=0.89, n=16
#   Understood ONLY poster meaning: Mean=2.44, SD=1.24, n=45
#   Did NOT understand language NOR poster meaning: Mean=2.10, SD=1.12, n=60
#   Kruskal-Wallis test: H=4.02, p=0.259
#  No significant differences between understanding groups.
#
# --- Trait: Manipulative ---
#   Understood BOTH language and poster meaning: Mean=2.19, SD=1.32, n=191
#   Understood ONLY language: Mean=2.19, SD=1.17, n=16
#   Understood ONLY poster meaning: Mean=2.02, SD=1.27, n=45
#   Did NOT understand language NOR poster meaning: Mean=1.57, SD=0.87, n=60
#   Kruskal-Wallis test: H=11.76, p=0.008
#   Significant differences found between understanding groups.
#   Effect size (epsilon squared): 0.028
# Small effect size (small practical impact).
# Participants who Understood BOTH language and poster meaning rated manipulative lower than those who 'Did NOT understand language NOR poster meaning' (rank-biserial r = -0.271, p = 0.001)
# Participants who Understood ONLY language rated manipulative lower than those who 'Did NOT understand language NOR poster meaning' (rank-biserial r = -0.311, p = 0.033)
#
# --- Trait: Boring ---
#   Understood BOTH language and poster meaning: Mean=2.78, SD=1.35, n=193
#   Understood ONLY language: Mean=2.88, SD=1.20, n=16
#   Understood ONLY poster meaning: Mean=2.53, SD=1.20, n=45
#   Did NOT understand language NOR poster meaning: Mean=2.72, SD=1.38, n=60
#   Kruskal-Wallis test: H=1.41, p=0.704
#  No significant differences between understanding groups.
#
# --- Trait: Misleading ---
#   Understood BOTH language and poster meaning: Mean=1.94, SD=1.22, n=190
#   Understood ONLY language: Mean=1.81, SD=0.98, n=16
#   Understood ONLY poster meaning: Mean=1.82, SD=1.05, n=45
#   Did NOT understand language NOR poster meaning: Mean=1.67, SD=0.95, n=60
#   Kruskal-Wallis test: H=1.60, p=0.660
#  No significant differences between understanding groups.
#
# --- Trait: Match_pol_comm ---
#   Understood BOTH language and poster meaning: Mean=1.67, SD=12.69, n=194
#   Understood ONLY language: Mean=2.94, SD=1.12, n=16
#   Understood ONLY poster meaning: Mean=3.33, SD=1.37, n=46
#   Did NOT understand language NOR poster meaning: Mean=-0.24, SD=18.21, n=62
#   Kruskal-Wallis test: H=4.06, p=0.255
#  No significant differences between understanding groups.
#
# --- Trait: Credible_typo_color ---
#   Understood BOTH language and poster meaning: Mean=3.34, SD=1.02, n=194
#   Understood ONLY language: Mean=2.94, SD=1.12, n=16
#   Understood ONLY poster meaning: Mean=3.26, SD=1.24, n=46
#   Did NOT understand language NOR poster meaning: Mean=-0.10, SD=18.23, n=62
#   Kruskal-Wallis test: H=2.90, p=0.408
#  No significant differences between understanding groups.
#
# --- Trait: Background ---
#   Understood BOTH language and poster meaning: Mean=3.27, SD=1.07, n=194
#   Understood ONLY language: Mean=3.19, SD=1.17, n=16
#   Understood ONLY poster meaning: Mean=0.91, SD=15.11, n=46
#   Did NOT understand language NOR poster meaning: Mean=1.52, SD=13.03, n=62
#   Kruskal-Wallis test: H=1.08, p=0.783
#  No significant differences between understanding groups.
#
# --- Trait: Typo_attention ---
#   Understood BOTH language and poster meaning: Mean=3.13, SD=1.08, n=194
#   Understood ONLY language: Mean=3.00, SD=1.21, n=16
#   Understood ONLY poster meaning: Mean=3.37, SD=1.10, n=46
#   Did NOT understand language NOR poster meaning: Mean=-0.21, SD=18.22, n=62
#   Kruskal-Wallis test: H=3.03, p=0.387
#  No significant differences between understanding groups.
#
# --- Trait: Support ---
#   Understood BOTH language and poster meaning: Mean=2.11, SD=7.38, n=194
#   Understood ONLY language: Mean=2.81, SD=0.91, n=16
#   Understood ONLY poster meaning: Mean=2.61, SD=1.02, n=46
#   Did NOT understand language NOR poster meaning: Mean=0.87, SD=12.93, n=62
#   Kruskal-Wallis test: H=1.34, p=0.719
#  No significant differences between understanding groups.
#
# --- Trait: Interested_in ---
#   Understood BOTH language and poster meaning: Mean=2.70, SD=1.16, n=194
#   Understood ONLY language: Mean=2.94, SD=1.06, n=16
#   Understood ONLY poster meaning: Mean=2.98, SD=1.09, n=46
#   Did NOT understand language NOR poster meaning: Mean=1.08, SD=12.97, n=62
#   Kruskal-Wallis test: H=3.29, p=0.349
#  No significant differences between understanding groups.
